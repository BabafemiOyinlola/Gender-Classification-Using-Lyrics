# %%
import re
import ast
import json
import pandas as pd

# %%
#read all files to combine

def read_file(filepath):
    data = ""
    with open(filepath) as f:
        data = f.readlines()
    return data

def convert_to_json(files):
    json_data = ""
    data = []
    
    for file in files:
        json_data = read_file(file)
        converted_form = [ast.literal_eval(item) for item in json_data]
        data.append(converted_form[0])
    
    return data

# %%
df = pd.DataFrame(columns={"year", "artist", "albums"})

def get_rows(file_data):
    rows = []
    for j in range(len(file_data)):
        for i in range(len(file_data[j])):
            row = {}
            row['year'] = file_data[j][i]['year']
            row['artist'] = file_data[j][i]['artist']
            row['albums'] = file_data[j][i]['albums']
            rows.append(row)
    return rows

# %%
#remove features or collaborations
def remove_features(dataframe):
    no_features = []
    feat_re = "[&,+\(\)/]"

    for index, row in df_unique_artists.iterrows():
        if re.search(feat_re, row['artist']) or "Featuring" in row['artist']:
            continue
        hold = []
        for album in row['albums']:
            track = row["albums"][album]
            hold.append(track)
        no_features.append({row['artist']: hold})
    return no_features

#get all songs for an artist
def get_all_artists_songs(temp):    
    nextline_re = re.compile(r"\n")
    artist_songs = []
    for item in temp:
        each_song = []
        artist = ""
        for key, value in item.items():
            artist = key
            for song in value:
                for title, album_tracks in song.items():
                    tracks = nextline_re.sub(" ", album_tracks)
                    each_song.append(tracks)
        artist_songs.append({artist:each_song})
        
    return artist_songs

# %%
#write song to files: a song on a line 
def save_each_artist(all_songs):
    for i in all_songs:
        for artist, all_tracks in i.items():
            filename = "/Users/oyinlola/Desktop/MSc Data Science/LENT TERM/SCC 413 - Applied Data Mining/Research Projects/Lyrics/word2vec/" + artist + ".txt"
            with open(filename, "w") as text_file:
                for track in all_tracks:
                    track = track + "\n"
                    text_file.write(track)
            print("Saved ", artist)

# %%
def combine_and_save(files):
    data = convert_to_json(word2vec)
    rows = get_rows(data)
    df = pd.DataFrame(rows)
    df_unique_artists = df.drop_duplicates(subset=['artist']) #select unique artists
    no_features = remove_features(df_unique_artists)
    artist_songs = get_all_artists_songs(no_features)
    save_each_artist(artist_songs)

# %%
files = ["rnb:hiphop1.txt", "rnb:hiphop2.txt", "rnb:hiphop3.txt", "rnb:hiphop4.txt"]
word2vec = ["word2vec.txt"]

# %%
combine_and_save(word2vec)
# Out:
# Saved  Kenny Rogers
# Saved  T.G. Sheppard
# Saved  The Oak Ridge Boys
# Saved  Don Williams
# Saved  Barbara Mandrell
# Saved  Waylon Jennings
# Saved  Willie Nelson
# Saved  Ronnie Milsap
# Saved  Conway Twitty
# Saved  The Bellamy Brothers
# Saved  Charley Pride
# Saved  Crystal Gayle
# Saved  Dottie West
# Saved  Debby Boone
# Saved  Emmylou Harris
# Saved  Eddie Rabbitt
# Saved  Dolly Parton
# Saved  Christy Lane
# Saved  George Jones
# Saved  Mickey Gilley
# Saved  Merle Haggard And Clint Eastwood
# Saved  Alabama
# Saved  Johnny Lee
# Saved  Razzy Bailey
# Saved  Waylon
# Saved  Anne Murray
# Saved  Merle Haggard
# Saved  Charly McClain
# Saved  Mel Tillis
# Saved  Elvis Presley
# Saved  Hank Williams Jr.
# Saved  Rosanne Cash
# Saved  Earl Thomas Conley
# Saved  Ronnie McDowell
# Saved  Steve Wariner
# Saved  Gene Watson
# Saved  Juice Newton
# Saved  Ed Bruce
# Saved  Ricky Skaggs
# Saved  Janie Frickie
# Saved  David Frizzell
# Saved  Sylvia
# Saved  George Strait
# Saved  Jerry Reed
# Saved  Michael Murphey
# Saved  Eddie Rabbitt With Crystal Gayle
# Saved  John Anderson
# Saved  Reba McEntire
# Saved  T.G. Sheppard And Karen Brooks
# Saved  Kenny Rogers And Sheena Easton
# Saved  Shelly West
# Saved  B.J. Thomas
# Saved  John Conlee
# Saved  Kenny Rogers Duet With Dolly Parton
# Saved  Lee Greenwood
# Saved  Exile
# Saved  The Statler Brothers
# Saved  The Kendalls
# Saved  Eddy Raven
# Saved  Vern Gosdin
# Saved  The Judds
# Saved  Nitty Gritty Dirt Band
# Saved  Jim Glaser
# Saved  John Schneider
# Saved  Mel McDaniel
# Saved  Gary Morris
# Saved  Ray Charles With Willie Nelson
# Saved  Sawyer Brown
# Saved  Highwaymen
# Saved  The Forester Sisters
# Saved  Dan Seals
# Saved  Crystal Gayle And Gary Morris
# Saved  Marie Osmond
# Saved  Judy Rodman
# Saved  Randy Travis
# Saved  Tanya Tucker
# Saved  Restless Heart
# Saved  Marie Osmond With Paul Davis
# Saved  T. Graham Brown
# Saved  Bellamy Brothers With the Forester Sisters
# Saved  Michael Johnson
# Saved  The O'Kanes
# Saved  Michael Martin Murphey
# Saved  Ricky Van Shelton
# Saved  K.T. Oslin
# Saved  Highway 101
# Saved  Kathy Mattea
# Saved  Rodney Crowell And Rosanne Cash
# Saved  The Desert Rose Band
# Saved  Keith Whitley
# Saved  Rodney Crowell
# Saved  Earl Thomas Conley With Emmylou Harris
# Saved  Dwight Yoakam
# Saved  Shenandoah
# Saved  Clint Black
# Saved  Patty Loveless
# Saved  Holly Dunn
# Saved  Garth Brooks
# Saved  Lorrie Morgan
# Saved  Travis Tritt
# Saved  Joe Diffie
# Saved  Paul Overstreet
# Saved  Mark Chesnutt
# Saved  Mike Reid
# Saved  Alan Jackson
# Saved  Dolly Parton With Ricky Van Shelton
# Saved  Doug Stone
# Saved  Diamond Rio
# Saved  Trisha Yearwood
# Saved  Lionel Cartwright
# Saved  Collin Raye
# Saved  Tracy Lawrence
# Saved  Wynonna
# Saved  Aaron Tippin
# Saved  Billy Ray Cyrus
# Saved  Vince Gill
# Saved  Sammy Kershaw
# Saved  John Michael Montgomery
# Saved  Toby Keith
# Saved  Tracy Byrd
# Saved  Clay Walker
# Saved  Reba McEntire With Linda Davis
# Saved  Doug Supernaw
# Saved  Faith Hill
# Saved  Neal McCoy
# Saved  Little Texas
# Saved  John Berry
# Saved  Tim McGraw
# Saved  Mary Chapin Carpenter
# Saved  Pam Tillis
# Saved  Wade Hayes
# Saved  Ty Herndon
# Saved  Shania Twain
# Saved  Jeff Carson
# Saved  Bryan White
# Saved  David Lee Murphy
# Saved  Martina McBride
# Saved  Lonestar
# Saved  Ricochet
# Saved  Rhett Akins
# Saved  Mindy McCready
# Saved  Deana Carter
# Saved  LeAnn Rimes
# Saved  Kevin Sharp
# Saved  Rick Trevino
# Saved  Trace Adkins
# Saved  Tim McGraw With Faith Hill
# Saved  Kenny Chesney
# Saved  Michael Peterson
# Saved  Jo Dee Messina
# Saved  Dixie Chicks
# Saved  Terri Clark
# Saved  Sara Evans
# Saved  Mark Wills
# Saved  Chely Wright
# Saved  Brad Paisley
# Saved  Chad Brock
# Saved  Lee Ann Womack With Sons Of The Desert
# Saved  Phil Vassar
# Saved  Jamie O'Neal
# Saved  Keith Urban
# Saved  Jessica Andrews
# Saved  Blake Shelton
# Saved  Cyndi Thomson
# Saved  Steve Holy
# Saved  Jo Dee Messina With Tim McGraw
# Saved  Chris Cagle
# Saved  Darryl Worley
# Saved  Rascal Flatts
# Saved  Gary Allan
# Saved  Joe Nichols
# Saved  Toby Keith Duet With Willie Nelson
# Saved  Dierks Bentley
# Saved  Gretchen Wilson
# Saved  Montgomery Gentry
