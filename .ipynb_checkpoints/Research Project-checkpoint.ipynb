# %% [markdown]
# ### Research Question:
# - How has R&B/Hip-Hop evolved from the 1990s - 2018?
# - What are the major changes that have occured?
# - Can the gender of the artist be predicted from the lyrics? (the assumption here is that the gender of the lyrics belongs to the owner of the song /artist )

# %% [markdown]
# ### Data Collection
# For this project, names of songs and artists are scraped from Billboard's Hot R&B/Hip-Hop Songs. These details are used to obtain the lyrics of these songs using the Genuis Lyric API and stored to a JSON file. The python script used to obtain the data can be is scraper.py

# %% [markdown]
# ### Data Preprocessing
# As expected, the data is messy as it is hence the need for preprocessing. Regular expressions are employed in cleaning the data as shown. The patterns to be captured are developed after inspecting the data.

# %%
import re
import nltk
import ftfy
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords

# %matplotlib inline

pd.options.display.max_rows = 420

# %%
df = pd.read_json("billboard_top_songs_lyrics.json")
df = df.drop_duplicates(keep='first')  #remove duplicates and keep the first occurence
df.loc[df.lyrics.isnull()]

# %%
# #re-visit
# data = df.copy()
# data.loc[386, 'lyrics'] = " i dont fuck with you you little stupid ass bitch i aint fuckin with you you little you little dumb ass bitch i aint fuckin with you i got a million trillion things id rather fuckin do than to be fuckin with you little stupid ass i dont give a fuck i dont give a fuck i dont i dont i dont give a fuck bitch i dont give a fuck about you or anything that you do dont give a fuck about you or anything that you doi heard you got a new man i see you takin a pic then you post it up thinkin that its makin me sick brr brr i see you calling i be makin it quick imma answer that shit like i dont fuck with you bitch i got no feelings to go i swear i had it up to here i got no ceilings to go i mean for real fuck how you feel fuck your two cents if it aint goin towards the bill yeah and everyday i wake up celebratin shit why cause i just dodged a bullet from a crazy bitch i stuck to my guns thats what made me rich thats what put me on thats what got me here thats what made me this and everything that i do is my first name these hoes chase bread aw damn she got a bird brain aint nothin but trill in me aw man silly me i just bought a crib three stories that bitch a trilogy and you know im rollin weed thats fuckin up the ozone i got a bitch that text me she aint got no clothes on and then another one text then your ass next and im gonna text your ass back likei dont fuck with you you little stupid ass bitch i aint fuckin with you you little you little dumb ass bitch i aint fuckin with you i got a million trillion things id rather fuckin do than to be fuckin with you little stupid ass i dont give a fuck i dont give a fuck i dont i dont i dont give a fuck bitch i dont give a fuck about you or anything that you do dont give a fuck about you or anything that you do i dont give a fuck i dont give a fuck i dont i dont i dont give a fuck bitch i dont give a fuck about you or anything that you do dont give a fuck about you or anything that you dogot a million things on my mind executive deals online limited amount of time chasin these dollar signs and you aint on your grind you might be able to find me up in the mgm casino in the d fuckin off fetti i coulda put on property from the bay to the murder mitten my niggas put murder missions she choose him thats her decision free my niggas in prison on the phone with a bitch who cant do shit for a pimp but make a nigga hella rich got a blunt in my dental goin ham in a rental on my way to sacramento late night arsenio im never sentimental go hard or go home listen barely harley im chromeless you might end up domeless i bet you she into me her cheddar she givin me i make a bitch stand outside forever like the statue of liberty rest in pimp pimp c underground king of the south i raise my styrofoam up and pour some drank in my mouth why you always coming around with bad news say you want me to win but hope i lose ass never rock with other niggas in the crew but them niggas cool its just thatbitch i aint fuck with you you little stupid ass bitch i aint fuckin with you you little you little dumb ass bitch i aint fuckin with you i got a million trillion things id rather fuckin do than to be fuckin with you little stupid ass i dont give a fuck i dont give a fuck i dont i dont i dont give a fuck bitch i dont give a fuck about you or anything that you do dont give a fuck about you or anything that you do i dont give a fuck i dont give a fuck i dont i dont i dont give a fuck bitch i dont give a fuck about you or anything that you do dont give a fuck about you or anything that you doi got a new chick that i gotta thank god for i got a new whip that i gotta thank a lot for yeah i got a lot but want a lot more yeah we in the buildin but im tryna take it to the top floor i swear i hear some new bullshit every day im wakin up it seems like nowadays everybody breakin up that shit can break you down if you lose a good girl i guess you need a bad bitch to come around and make it up i guess drama makes for the best content everything got a bad side even a conscience now youre drinkin til your unconscious feel me when you get a fine bitch just dont forget to read the fine print life got me meditatin like im in the himalayas keep it g with the l lit on me like the elevator yeah i know that karmas too real so i hope you doin cool but still stupid ass bitch i aint fuckin with you little stupid ass i aint fuckin with i aint fuckin i aint i aint fuckin with you i aint fuckin with you "
# data.loc[376, 'lyrics'] = " intro beyoncéive been drinking ive been drinking i get filthy when that liquor get into me ive been thinking ive been thinking why cant i keep my fingers off you baby i want you na na why cant i keep my fingers off you baby i want you na naverse 1 beyoncé cigars on ice cigars on ice feeling like an animal with these cameras all in my grill flashing lights flashing lights you got me faded faded faded baby i want you na na cant keep your eyes off my fatty daddy i want you na na drunk in love i want youbridge beyoncé we woke up in the kitchen saying how the hell did this shit happen oh baby drunk in love we be all night last thing i remember is our beautiful bodies grinding off in that club drunk in lovehook beyoncé we be all night love love we be all night love loveverse 2 beyoncé we be all night and everything alright no complaints for my body so fluorescent under these lights boy im drinking walking in my lassemblage im rubbing on it rubrubbing if you scared call that reverend boy im drinking imma bring it right oñly bring you a gangster wife louis sheets  he sweat it out like washed rags he wet it up boy im drinking im singing on the mic to my boys toys then i fill the tub up halfway then ride it with my surfboard surfboard surfboard graining on that wood graining graining on that wood im swerving on that swerving swerving on that big body been serving all this swerve surfing all of this good goodbridge we woke up in the kitchen saying how the hell did this shit happen oh baby drunk in love we be all night last thing i remember is our beautiful bodies grinding off in that club drunk in lovehook we be all night love love we be all night love loveverse 3 jay z hold up hold up i do say its the shit if i do say so myself if i do say so myself if i do say so myself hold up stumble all in the house tryna backup all of that mouth that you had all in the car talking bout you the baddest bitch thus far talking bout you be repping that 3rd wanna see all that shit that i heard know i sling clint eastwood hope you can handle this curve uh foreplay in a foyer fucked up my warhol slid the panties right to the side aint got the time to take drawers off on sight catch a charge i might beat the box up like mike in 97 i bite im ike turner turn up baby know i dont play now eat the cake anna mae said eat the cake anna mae im nice for yall to reach these heights you gon need g3 4 5 6 flights sleep tight we sex again in the morning your breasteses is my breakfast we going in we be all nighthook beyoncé we be all night love love we be all night love loveverse 4 beyoncé never tired never tired i been sippin thats the only thing thats keeping me on fire me on fire didnt mean to spill that liquor all on my attire ive been drinking watermelon i want your body right here daddy i want you right now cant keep your eyes off my fatty daddy i want youhook beyoncé we be all night love love we be all night love love "
# data.loc[371, 'lyrics'] = " intro ay ay ay good to see you come on in lets go yeah lets go alright alright ok uh alright ok alright okreturn of the mack get it what it is what it does what it is what it isnt looking for a better way to get up out of bed instead of getting on the internet and checking a new hippy get up thrift shop pimp strut walking little bit of humble little bit of cautious somewhere between like rocky and cosby sweater gang nope nope yall cant copy yup bad moon walking this here is our party my posses been on broadway and we did it our way grown music i shed my skin and put my bones into everything i record to it and yet im on let that stage light go and shine on down got that bob barker suit game and plinko in my style money stay on my craft and stick around for those pounds but i do that to pass the torch and put on for my town trust me on my independent shit hustlin chasing dreams since i was 14 with the four track bussing halfway cross that city with the backpack fat cat crushinglabels out here now they cant tell me nothing we give that to the people spread it across the country labels out here now they cant tell me nothing we give it to the people spread it across the countryhere we go back this is the moment tonight is the night well fight till its over so we put our hands up like the ceiling cant hold us like the ceiling cant hold us here we go back this is the moment tonight is the night well fight till its over so we put our hands up like the ceiling cant hold us like the ceiling cant hold usnow can i kick it thank you yeah im so damn grateful i grew up really wanted gold fronts but thats what you get when wu tang raised you yall cant stop me go hard like i got an 808 in my heart beat and im eating at the beat like you gave a little speed to a great white shark on shark week raw tell me go up gone deuces goodbye i got a world to see and my girl she wanna see rome caesar make you a believer now i never ever did it for a throne that validation comes from giving it back to the people now sing a song and it goes like raise those hands this is our party we came here to live life like nobody was watching i got my city right behind me if i fall they got me learn from that failure gain humility and then we keep marching ourselveshere we go back this is the moment tonight is the night well fight till its over so we put our hands up like the ceiling cant hold us like the ceiling cant hold us here we go back this is the moment tonight is the night well fight till its over so we put our hands up like the ceiling cant hold us like the ceiling cant hold us and so we put our hands up and so we put our hands uplets gona na na na na na na na aha hey and all my people sayna na na na na na na na thats right feels good hey and all my people sayna na na na na na na na its alright oh oh oh oh oh oh oh oh and all my people sayna na na na na na na na macklemorehere we go back this is the moment tonight is the night well fight till its over so we put our hands up like the ceiling cant hold us like the ceiling cant hold us here we go back this is the moment tonight is the night well fight till its over so we put our hands up like the ceiling cant hold us like the ceiling cant hold us "
# data.loc[360, 'lyrics'] = " im the fin man you dont get it do ya type of money everybody acting like they knew ya go uptown new york city b some spanish girls love me like im aventura tell uncle luke im out in miami too clubbing hard fin women aint much to do wrist bling got a condo up in biscayne still getting brain from a thang aint s changed how you feel how you feel how you feel twenty five sittin on twentyfive mil uh im in the building and im feeling myself rest in peace mac dre imma do it for the bay okay getting paid well holla wen ever that stop my team good we dont really need a mascot tell tune light one pa it like a relay ymcmb you ns more ymca me freddie marley marl at the cribbo shout goes out to niko j and chubbs shout to gibbo we got santa margarita by the liter she know even if im fin with her i dont really need her ahhh thats how you feel man thats really how you feel cause the pimpin ice cold all these bes wanna chill i mean maybe she wont then again maybe she will i can almost guarantee she know the deal real n wassapnow she want a photo ya you already know though you only live once thats the motto n yolo we bout it every day every day every day like we sittin on the bench n we dont really play every day every day f what anybody say cant see em cause the money in the way real n wassupone time f one time im calling ns out like the umpire seven grams in the blunt almost drowned in her p so i swam to her butt its eastside we in this b wish a n would like a tree in this b and if a leaf fall put some weed in that b thats my mo add a b to that s im fed up torn down im twisted door knob talk stupid off with your head n money talks and mr ed ya im so young money got a drum on the gun energizer bunny funny how honey aint sweet like sugar aint s sweet ns on the street like hookers i tongue kiss her other tongue skeet skeet skeet water gun oh my god becky look at her butttunechinow she want a photo ya you already know though you only live once thats the motto n yolo we bout it every day every day every day like we sittin on the bench n we dont really play every day every day f what anybody say cant see em cause the money in the way real n wassupwassap wassap real n wassup real n wassupnow she want a photo ya you already know though you only live once thats the motto n yolo we bout it every day every day every day like we sittin on the bench n we dont really play every day every day f what anybody say cant see em cause the money in the way real n wassupwassap wassap "
# data.loc[295, 'lyrics'] = " whats happenin dis ya boy lil jon bme clik whats up 40 whats happenin whats up sean paul whats happenin hey now ladies and gentlemen its about dat time to turn this thang on out now let me see everybody do this hey lets gosnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it aysnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it aysnap ya fingers and then rock wit it do it do it do it do it gon drop wit it do a step wit it put ya hips wit it all my ladies let me see ya put a twist wit it you cant do like me im by myself i do it so good i dont need nobody else whats happenin whats up got da purk fired up whats happenin whats up got patron in my cup i pop i drank im on patron and purk i cant thank im blowed to tha do dont know how tha hell im gettin homesnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it aysnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it aystraight from da bay posted in tha a bout to hit tha club we been mobbin all day drinkin some rusty dyinoff patron vip status strapped wit my chrome look around tha club what do i see everybody rockin from side to side to tha beat snappin they fingers bouncin to tha groove all by they self thats tha new move nigga where im from we like to go dumb im soakin up tha game im seein how its done i ask shawty what they call it she said tha pool palace straight from bank head i said you good at it do what cha do you and ya crew they even got playas and thugs doin it too the mo that i drank tha more its lookin smooth its nothin to a boss i can do tha shit toosnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it aysnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it aychillin in tha bip yeah we get crunk niggas poppin bottles and these bitches gettin drunk rollin up tha kush put it in tha air im throwin up tha es to let em know we in here brand new shoes brand new tool pull out tha ol school cause im feelin real cool yeah im from tha a so im leanin and rockin snappin my fingers then reachin for my glock bitch reppin my block bitch straight from tha deck when you snap ya fingers shawty gotta jerk ya neck smokin on tha best we dont fuck wit dat mess i bet you cant do it do it do it like this yeah im back to tha track back to tha snap one two step then you gotta lean back dis is how we do it in tha a town and if you aint know this how it goes downsnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it aysnap ya fingers do ya step you can do it all by yo self let me see you do it ay let me see you do it ay hey hey "
# data.loc[242, 'lyrics'] = " cmon cmon yeah cmon yeah uh oooh uh oh oh ohif the partys where your at just let me knowdont be trippin when you see us in the club just show a little love represent your side like me cause round here if you slick you pick a hot one ride shotgun couple of em got one belvedere in the rear of the club pulled up on dubs and we bout to go and buy the bar up so so for sure we aint playin hang with no lames hit the park and sayinay where the party at girls is on the way where the bacardi at models and models talkin all a that know i cant forget about my thugs where the party at and all my girls where the party at off in the club where the party at if the partys where youre at let me hear you say uh oooh uh oh oh oh if the partys where youre at just let me knowall the girls in the club in they best outfits just showin that skin tryna make a nigga wanna spit where you been girl you and your friend need to come to the back where we got it locked down in your white tshirt or a threepiece suit dont matter what you wear all that matters is who you with some jiggy and some are straight grindin all up in the club just to have a good timeay where the party at girls is on the way where the bacardi at models and models talkin all a that know i cant forget about my thugs where the party at and all my girls where the party at off in the club where the party at if the partys where youre at let me hear you say uh oooh uh oh oh ohif the partys where youre at just let me know you got to show me where that party at dirty somewhere where its crackin right around onethirty never get done too early come in as is doorags and tims im rollin past his his little jag and benz with the rolls not the one with the stem the one with the rims the one that seem to make more enemies than friends im slidin in past doors both eyes closed both arms rose both charms froze with the so so  de dot f im buyin bottles bottles until it aint none left im quick to go left i blaze with no rep i jams more than def baby show me the club im like hey where the bacardi at come and mix it with the cris baby whats wrong with that we in the v i p twisted down right spliffed it two way and ooh they makin it like you missed itay where the party at girls is on the way where the bacardi at models and models talkin all a that know i cant forget about my thugs where the party at and all my girls where the party at off in the club where the party at if the partys where youre at let me hear you say uh oooh uh oh oh oh if the partys where youre at let me hear you say uh oooh uh oh oh oh if the partys where youre at just let me knowleft side just put your hands up throw em up right side just put your hands up throw em up everybody put your hands up throw em up when the beat come back around erybody do it againdo the eastside run this mutha for ya hell yeah do my southside run this mutha oh ya hell yeah and them haters aint hittin on aint talkin bout us and they look like if the partys where youre at let me hear you say "
# data.loc[161, 'lyrics'] = " last night you were so into it you told me secrets that youve never told a soul you were so nervous and yet oh so comfortable as we explored your image of lovei drank your wine as you taste mine i kissed your lips you felt my mind slip into your soul i almost cried cause it was so beautifullast night i was inside of you last night while making love to you i saw the sun the moon the mountains and the rivers i saw heaven when i made sweet love to youlast night there was no planning it it was so special and so very innocent we talked of memories our favorite fantasies as we explored our visions of lovedeep in the night right by the fireside you felt my candlelight in your soul you felt incredible i started to explode i almost cried cause it was so beautifullast night i was inside of you last night while making love to you i saw the sun the moon the mountains and the rivers i saw heaven when i made sweet love to yousunlight red red roses the scent of you it calms the heart the sight of you i fall apartmoonlight the things we notice when were in love thats when it comes and im so im so in lovelast night i was inside of you last night while making love to you i saw the sun the moon the mountains and the rivers i saw heaven when i made sweet love to you babylast night i was inside of you last night while making love to you i saw the sun the moon the mountains and the rivers i saw heaven when i made sweet love to you babylast night i was inside of you last night while making love to you i saw the sun the moon the mountains and the rivers i saw heaven when i made sweet love to you "
# data.loc[148, 'lyrics'] = " baby baby baby baby help me out here cmonwhile all the time that i was loving you you were busy loving yourself i would stop breathing if you told me to now youre busy loving someone elseeleven years out of my life besides the kids i have nothing to show wasted my years a fool of a wife i shoulda have left your ass a long time agowell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearswell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearsi was your lover and your secretary working every day of the week was at the job when no one else was there helping you get on your feeteleven years of sacrifice and you can leave me at the drop of a dime swallowed my fears stood by your side i shoulda left your ass a thousand timeswell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearswell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearsi know there are no guarantees see in love you take your chances but somehow it seems fucked up to me just look at the circumstancesthrough sickness and health till death do us part those were the words that we said from our heartsso now when you say that youre leaving me i dont get that part hell noi was your lover and your secretary working every day of the week was at the job when no one else was there helping him get on his feeteleven years of sacrifice and he can leave me at the drop of a dime swallowed my fears stood by your side i shoulda left your ass a thousand timeswell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearswell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearswell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearswell im not gon cry im not gon cry im not gon shed no tears no im not gon cry its not the time cuz youre not worth my tearsi said he was never ever ever ever ever ever ever ever worth any of these tears he wasnt worth it was he worth it ladies hell no you know what we aint gonna miss him fuck it but guess what "
# data.loc[146, 'lyrics'] = " everyone falls in love sometimes sometimes its wrong and sometimes its right for every win someone must fail but there comes a point when when we exhale yeah yeah sayshoop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop all you gotta do is say shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doopsometimes youll laugh sometimes youll cry life never tells us the whens or whys when youve got friends to wish you well youll find your point when you will exhale yeah yeah sayshoop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doophearts are often broken when there are words unspoken in your soul theres answers to your prayers if youre searching for a place you know a familiar face somewhere to go you should look inside yourself youre halfway theresometimes youll laugh sometimes youll cry life never tells us the whens or whys but when youve got friends to wish you well youll find your point when you will exhale yeah yeah sayshoop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop shoop shoop shoop be doop "
# data.loc[119, 'lyrics'] = " lately there seems to be some insecurities about the way i feel where i wanna be boy you know its with you no one can do the things you do to menever to be mistaking long as its love were making therell be no hesitating you and me and it always will be and i wont leave your side cause you knowlove will be right here be right here right here be right here no fear have no fear no tears love is heretrue love some dont believe in thats just what im giving im gonna keep it strong ill be holding on to you no one can do me like you do its truesure as the sun is shining our love will keep on climbing theres gonna be some rain gonna be some pain but as long as i know boy time will show our love will grow and i knowlove will be right here be right here right here be right here no fear have no fear no tears love is herelove will be right here be right here right here be right here no fear have no fear no tears love is herewont let go you should know this thing is real no questions just listen to you heart and love will be rightbaby whats the problem its seems like were having trouble you dont seem to understand the life i lead aint doublemy heart belongs to you and only you and you know its true a phony imitation just wont do relax your mindim not the kind who runs around and wastes time other fine brothers just dont compare ill be there i swear far or near have no fear i dont care you can count on me im right hereright here be right here right here be right here no fear have no fear no tears love is hereright here be right here right here be right here no fear have no fear no tears love is hereright here be right here right here be right here no fear have no fear no tears love is hereright here be right here right here be right here no fear have no fear "
# data.loc[93, 'lyrics'] = " boy when you look at me boy do you judge me by my cover ya got to be kiddin me to think that im that kind of loveri dont mean to disagree sorry you cant buy my kisses open your heart and see true love comes for freeim keepin my heart open hopin you wont stab me in it cause ive been in love before and when i had to pay i didntill lose my sanity tryin to measure your intentions what do you want from me how much will it beno more than youre willing to give cause you wont pay nothin for this good lovin its for freeand i wont make you promises ill just do all that i can to be your lover cause i understandthe best things in life are free now that ive discovered what you mean to me the best things in life are free now that weve got each other the best things in life are freei know you are my baby my one and only baby you said it twice ill say it thrice my baby baby babyi got so much love for you and its easy to give it when i know you feel the same way toothats all i expect from you just do all that you can to be my lover cause i understand i dothe best things in life are free now that ive discovered what you mean to me the best things in life are free now that weve got each other the best things in life are freeno more than youre willing to give cause you wont pay nothin for this good lovin its for freeand i wont make you promises you see im gonna be m gonna be were gonna be im gonna be the very best i can to be your lover cause i understandthe best things in life are free now that ive discovered what you mean to me the best things in life are free now that weve got each other the best things in life are free "
# data.loc[82, 'lyrics'] = " this will be the day that you will hear me say that i will never run awayi am here for you love is meant for two now tell me what youre gonna doif i gave you diamonds and pearls would you be a happy boy or a girl if i could i would give you the world but all i can do is just offer you my lovewhich one of us is right if we always fight why cant we just let love decide let love decideam i the weaker man because i understand that love must be the master plan love is the master planif i gave you diamonds and pearls would you be a happy boy or a girl if i could i would give you the world all i can do is just offer you my loved to the i to the a to the m o to the n to the d to the pearls of love d to the i to the a to the m to the m o to the n to the d to the pearls of lovethere will come a time there will come a time when love will blow your mind blow your mind and everything youll look for youll find take a look insidethat will be the time that will be the time that everything will shine forever so bright it makes you colorblind you will be color blindif i gave you diamonds and pearls would you be a happy boy or a girl if i could i would give you the world all i can do is just offer you my loveif i gave you diamonds and pearls pearls would you be a happy boy or a girl yeah yeah if i could i would give you the world give you the world all i can do is just offer you my love all i can doif i gave you diamonds and pearls diamonds would you be would you would you would ya would ya would ya be happy little baby if i could i would give you the world "
# data.loc[53, 'lyrics'] = " come inside take off your coat ill make you feel at home now lets pour a glass of wine cause now were all alone ive been waiting for you girl just let me hold you close to me cause ive been dying for you girl to make love to megirl you make me feel real good we can do it til we both wake up girl you know im hooked on you and this is what ill doi wanna sex you all night you make me feel good i wanna rub you down i wanna sex you uplet me take off all your clothes disconnect the phone so nobody knows let me light a candle so we can make it better makin love until we drowngirl you know it feels real good we can do it til we both wake up girl you know im hooked on you and this is what ill doi wanna sex you up makin love until we drown i wanna sex you upall i wanna do is i wanna sex you up all night girl you make me feel good i wanna rub you down i wanna sex you upmake sweet lovin all night long i wanna sex you up feels so right it cant be wrong dont be shy girl rescue me i wanna sex you up open up your heart and ill set you free "

# %%
#re-visit
data = data.dropna(subset=['lyrics'], axis=0)
data = data.reset_index(drop=True)

# %%
sections_re = re.compile(r"(\[)?\[(.*?)\](\])?") #anything in square bracket
par_re = re.compile(r"\((.*?)\)") #anything in parentheses
verse_re = re.compile(r"([0-9a-z ]+)?verse(:)?[\s](\w.)?") #verse headers
repeat_re = re.compile(r"(\n)?repeat[a-z .\(\)\d]+") #repeat headers
chorus_re = re.compile(r"chorus([a-z .\(\)\d:]+)?") #chorus headers
hook_re = re.compile(r"(\n)?hook[:| |\n]([a-z .\(\)\d]+)?") #hook headers
title_re = re.compile(r"(\n)?title:([\w+ ]+)?") #title headers
singer_re = re.compile(r"([a-z &]+)?\w+:") #name of singer indicating who is singing currently especially for featured artists 
punt_re = re.compile(r"[^a-zA-Z'&\n ]+") #irrelevant puctuations

tokenise_re = re.compile(r"(\[[^\]]+\]|[-'\w]+|[^\s\w\[']+)") #([]|words|other non-space)

def preprocess(text):
    text = text.lower()
    p_text = sections_re.sub("", text)
    p_text = par_re.sub("", p_text)
    p_text = verse_re.sub("", p_text)
    p_text = repeat_re.sub("", p_text)
    p_text = chorus_re.sub("", p_text)
    p_text = hook_re.sub("", p_text)
    p_text = title_re.sub("", p_text)
    p_text = singer_re.sub("", p_text)
    p_text = punt_re.sub("", p_text)
    p_text = ftfy.fix_text(p_text)
    return p_text.lower()  #return lyrics in the same case

def replace_apostrophe(lyrics):
    full_text = ""
    for text_line in lyrics.split("\n"):
        for text in text_line.split(" "):
            if "'" in text:
                shortened = text.split("'")
                if shortened[1] == "ll":
                    text = shortened[0] + " will"
                elif shortened[1] == "m":
                    text = shortened[0] + " am"
                elif shortened[1] == "ve":
                    text = shortened[0] + " have"
                elif shortened[1] == "re":
                    text = shortened[0] + " are"
                elif shortened[1] == "cause":
                    text = "because"
                elif shortened[1] == "":
                    text = shortened[0] + "g"
                elif text == "y'all":
                    text = "you all"
                elif text == "'em":
                    text = "them"
                elif text == "'lone":
                    text = "alone"
                elif text == "c'mon":
                    text = "common"
                elif shortened[1] == "t" and shortened != "ain":
                    text = shortened[0] + " not"
        full_text = full_text + " " + text
    return full_text
            
     
def tokenise(text):
    return tokenise_re.findall(text)

nltk.download('stopwords')
nltk_stopwords = set(stopwords.words('english'))

def stopwords_file(file):
    with open(file) as f:
        items = []
        lines = f.readlines()
        for line in lines:
            items.append(line.strip())
    return items

stanford_stopwords = stopwords_file("stanford_stopwords.txt")

def remove_stopwords(tokens):
    nltk_filtered = [word for word in tokens if word not in nltk_stopwords]
    filtered = [word for word in nltk_filtered if word not in stanford_stopwords]
    return filtered

def frequency_analysis(tokens):
    freq = nltk.FreqDist(tokens)
    for key,val in freq.most_common(20):
        print(key,val,sep="\t")
    freq.plot(20, cumulative=False)
    
    
#handle 'll, 'm and the likes in lyrics
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/oyinlola/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Create an object for each song

# %%
class Song:
    def __init__(self, obj={}):
        self.song = obj.song
        self.artist = obj.artist
        self.lyrics = obj.lyrics
        self.year = obj.year
    
    def tokenize(self):
        token = []
        for line in self.lyrics.split("\n"):
            tk = tokenise(line)
            token.extend(tk)
        self.token = token
        self.token_fql = Counter(token)
        return self.token

# %%
music_library = []
all_tokens = []
tokens_1990s = []
tokens_2000s = []

# %%
#populate tokens
for index, row in data.iterrows():
    single = Song(row)
    single.lyrics = preprocess(single.lyrics)
    single.lyrics = replace_apostrophe(single.lyrics)
    
    music_library.append(single)
    token = single.tokenize()
    all_tokens.extend(token)
    if single.year < 2000:
        tokens_1990s.extend(token)
    elif single.year > 1999:
        tokens_2000s.extend(token)

# %%
filter_1990s_token = remove_stopwords(tokens_1990s)
filter_2000s_token = remove_stopwords(tokens_2000s)

filter_1990s_token_fql = Counter(filter_1990s_token)
filter_2000s_token_fql = Counter(filter_2000s_token)

filter_1990s_token_fql.most_common()
# len(filter_1990s_token)
# Out:
# [('baby', 418),
#  ('love', 245),
#  ('yeah', 242),
#  ('time', 134),
#  ('know', 130),
#  ('go', 105),
#  ('girl', 105),
#  ('way', 87),
#  ('night', 81),
#  ('babe', 78),
#  ('tonight', 78),
#  ('alone', 77),
#  ('shit', 77),
#  ('back', 74),
#  ('right', 70),
#  ('heart', 68),
#  ('oh', 67),
#  ('day', 67),
#  ('duchess', 67),
#  ('crazy', 65),
#  ('away', 59),
#  ('say', 55),
#  ('body', 52),
#  ('need', 51),
#  ('bitch', 51),
#  ('guido', 50),
#  ('mind', 49),
#  ('uh', 49),
#  ('life', 48),
#  ('man', 46),
#  ('boy', 42),
#  ('see', 42),
#  ('name', 42),
#  ('duke', 42),
#  ('feel', 40),
#  ('one', 40),
#  ('niggas', 40),
#  ('world', 37),
#  ('good', 35),
#  ('lady', 35),
#  ('mine', 32),
#  ('wrong', 32),
#  ('real', 28),
#  ('hey', 28),
#  ('yes', 28),
#  ('minute', 28),
#  ('lonely', 28),
#  ('around', 27),
#  ('low', 26),
#  ('true', 26),
#  ('inside', 26),
#  ('together', 25),
#  ('gone', 25),
#  ('nobody', 25),
#  ('want', 24),
#  ('afraid', 24),
#  ('slow', 24),
#  ('friend', 24),
#  ('bills', 24),
#  ('long', 23),
#  ('smile', 23),
#  ('ooh', 23),
#  ('feet', 23),
#  ('die', 23),
#  ('thing', 22),
#  ('stay', 22),
#  ('ride', 22),
#  ('something', 22),
#  ('citizen', 22),
#  ('yuh', 22),
#  ('us', 21),
#  ('woman', 21),
#  ('beat', 21),
#  ('eyes', 21),
#  ('huh', 21),
#  ('escapade', 20),
#  ('stop', 20),
#  ('money', 20),
#  ('game', 20),
#  ('phone', 20),
#  ('else', 20),
#  ('nigga', 20),
#  ('forever', 19),
#  ('goes', 19),
#  ('okay', 19),
#  ('free', 19),
#  ('fire', 19),
#  ('times', 19),
#  ('place', 19),
#  ('chance', 19),
#  ('forth', 19),
#  ('feat', 19),
#  ('home', 18),
#  ('cry', 18),
#  ('cool', 18),
#  ('soul', 18),
#  ('hands', 18),
#  ('dear', 18),
#  ('california', 18),
#  ('king', 18),
#  ('hand', 18),
#  ('wanna', 18),
#  ('today', 17),
#  ('sing', 17),
#  ('strong', 17),
#  ('alive', 17),
#  ('everything', 17),
#  ('poison', 17),
#  ('play', 17),
#  ('going', 17),
#  ('walk', 17),
#  ('romantic', 17),
#  ('ahh', 17),
#  ('tight', 16),
#  ('self', 16),
#  ('things', 16),
#  ('boys', 16),
#  ('ya', 15),
#  ('ho', 15),
#  ('face', 15),
#  ('understand', 15),
#  ('nothing', 15),
#  ('control', 15),
#  ('jackson', 15),
#  ('provide', 15),
#  ('pray', 15),
#  ('well', 14),
#  ('bass', 14),
#  ('pain', 14),
#  ('work', 14),
#  ('friends', 14),
#  ('side', 14),
#  ('shame', 14),
#  ('drugs', 14),
#  ('blues', 13),
#  ('darling', 13),
#  ('sight', 13),
#  ('high', 13),
#  ('war', 13),
#  ('alright', 13),
#  ('damn', 13),
#  ('days', 13),
#  ('grind', 13),
#  ('knew', 13),
#  ('personal', 13),
#  ('williams', 13),
#  ('crossroads', 13),
#  ('whoa', 12),
#  ('head', 12),
#  ('ready', 12),
#  ('please', 12),
#  ('fine', 12),
#  ('ways', 12),
#  ('rain', 12),
#  ('door', 12),
#  ('affection', 12),
#  ('someone', 12),
#  ('lean', 12),
#  ('kid', 12),
#  ('hoe', 12),
#  ('enough', 11),
#  ('ecstasy', 11),
#  ('dream', 11),
#  ('show', 11),
#  ('lord', 11),
#  ('change', 11),
#  ('yah', 11),
#  ('honey', 11),
#  ('keep', 11),
#  ('desire', 11),
#  ('emotions', 11),
#  ('memories', 11),
#  ('paid', 11),
#  ('gun', 11),
#  ('wet', 11),
#  ('remix', 11),
#  ('queen', 11),
#  ('everybody', 10),
#  ('nation', 10),
#  ('people', 10),
#  ('care', 10),
#  ('anything', 10),
#  ('g', 10),
#  ('said', 10),
#  ('sweat', 10),
#  ('wife', 10),
#  ('sleep', 10),
#  ('apart', 10),
#  ('fantasy', 10),
#  ('end', 10),
#  ('thang', 10),
#  ('running', 10),
#  ('house', 10),
#  ('death', 10),
#  ('person', 10),
#  ('line', 10),
#  ('exclusivity', 10),
#  ('yet', 10),
#  ('mean', 10),
#  ('heaven', 10),
#  ('god', 10),
#  ('class', 10),
#  ('direction', 10),
#  ('school', 10),
#  ('homies', 10),
#  ('rihanna', 10),
#  ('mars', 10),
#  ('stupid', 10),
#  ('fuck', 10),
#  ('left', 10),
#  ('ayy', 10),
#  ('lover', 9),
#  ('give', 9),
#  ('try', 9),
#  ('talk', 9),
#  ('made', 9),
#  ('song', 9),
#  ('bad', 9),
#  ('dreams', 9),
#  ('start', 9),
#  ('find', 9),
#  ('share', 9),
#  ('fool', 9),
#  ('hard', 9),
#  ('bop', 9),
#  ('come', 9),
#  ('like', 9),
#  ('gold', 9),
#  ('brother', 9),
#  ('doubt', 9),
#  ('park', 9),
#  ('move', 9),
#  ('hide', 9),
#  ('confused', 9),
#  ('sir', 9),
#  ('hooray', 9),
#  ('girls', 9),
#  ('chill', 9),
#  ('raindrops', 9),
#  ('kids', 9),
#  ('pony', 9),
#  ('rap', 9),
#  ('scrubs', 9),
#  ('week', 8),
#  ('blow', 8),
#  ('break', 8),
#  ('much', 8),
#  ('air', 8),
#  ('games', 8),
#  ('sweet', 8),
#  ('speak', 8),
#  ('two', 8),
#  ('flow', 8),
#  ('sun', 8),
#  ('police', 8),
#  ('bit', 8),
#  ('round', 8),
#  ('goodbye', 8),
#  ('lesson', 8),
#  ('stone', 8),
#  ('weak', 8),
#  ('another', 8),
#  ('brot', 8),
#  ('hotel', 8),
#  ('feeling', 7),
#  ('got', 7),
#  ('fun', 7),
#  ('music', 7),
#  ('tenderness', 7),
#  ('hit', 7),
#  ('ring', 7),
#  ('never', 7),
#  ('lights', 7),
#  ('look', 7),
#  ('cash', 7),
#  ('town', 7),
#  ('yesterday', 7),
#  ('close', 7),
#  ('seen', 7),
#  ('morning', 7),
#  ('bed', 7),
#  ('woo', 7),
#  ('laugh', 7),
#  ('wanted', 7),
#  ('word', 7),
#  ('three', 7),
#  ('stars', 7),
#  ('duck', 7),
#  ('really', 7),
#  ('hell', 7),
#  ('promise', 7),
#  ('pride', 7),
#  ('check', 7),
#  ('moving', 7),
#  ('em', 7),
#  ('eminem', 7),
#  ('delay', 7),
#  ('mode', 7),
#  ('rzte', 7),
#  ('unheilig', 7),
#  ('ozone', 7),
#  ('coldplay', 7),
#  ('account', 7),
#  ('mindy', 7),
#  ('better', 6),
#  ('reason', 6),
#  ('lie', 6),
#  ('wonder', 6),
#  ('sand', 6),
#  ('guys', 6),
#  ('city', 6),
#  ('plan', 6),
#  ('far', 6),
#  ('behind', 6),
#  ('garden', 6),
#  ('lovers', 6),
#  ('fly', 6),
#  ('blind', 6),
#  ('make', 6),
#  ('dance', 6),
#  ('hair', 6),
#  ('listen', 6),
#  ('dawn', 6),
#  ('everywhere', 6),
#  ('ha', 6),
#  ('nice', 6),
#  ('disguise', 6),
#  ('quick', 6),
#  ('hurry', 6),
#  ('leave', 6),
#  ('cold', 6),
#  ('wild', 6),
#  ('demanding', 6),
#  ('health', 6),
#  ('open', 6),
#  ('kiss', 6),
#  ('loving', 6),
#  ('warm', 6),
#  ('problems', 6),
#  ('b', 6),
#  ('chair', 6),
#  ('men', 6),
#  ('london', 6),
#  ('kisses', 6),
#  ('summertime', 6),
#  ('found', 6),
#  ('saying', 6),
#  ('ever', 6),
#  ('cardinal', 6),
#  ('last', 6),
#  ('beatrice', 6),
#  ('child', 6),
#  ('take', 6),
#  ('ah', 6),
#  ('bloom', 6),
#  ('fox', 6),
#  ('aggression', 6),
#  ('worry', 6),
#  ('amazing', 6),
#  ('sleeping', 6),
#  ('homie', 6),
#  ('maffay', 6),
#  ('jovi', 6),
#  ('&', 6),
#  ('avenue', 6),
#  ('jayz', 6),
#  ('working', 6),
#  ('roll', 6),
#  ('toes', 6),
#  ('seconds', 6),
#  ('nose', 6),
#  ('ass', 6),
#  ('pills', 6),
#  ('pretend', 6),
#  ('excited', 6),
#  ('incessantly', 6),
#  ('limit', 5),
#  ('sorry', 5),
#  ('unite', 5),
#  ('best', 5),
#  ('needs', 5),
#  ('finn', 5),
#  ('energy', 5),
#  ('deep', 5),
#  ('dead', 5),
#  ('unwind', 5),
#  ('clothes', 5),
#  ('sea', 5),
#  ('chest', 5),
#  ('happiness', 5),
#  ('despair', 5),
#  ('exciting', 5),
#  ('room', 5),
#  ('difference', 5),
#  ('kind', 5),
#  ('destiny', 5),
#  ('lies', 5),
#  ('though', 5),
#  ('temple', 5),
#  ('benefit', 5),
#  ('late', 5),
#  ('coast', 5),
#  ('rains', 5),
#  ('moment', 5),
#  ('passion', 5),
#  ('new', 5),
#  ('arms', 5),
#  ('rush', 5),
#  ('wait', 5),
#  ('sugar', 5),
#  ('words', 5),
#  ('century', 5),
#  ('power', 5),
#  ('tell', 5),
#  ('fall', 5),
#  ('exclusively', 5),
#  ('romance', 5),
#  ('blast', 5),
#  ('falling', 5),
#  ('grooving', 5),
#  ('let', 5),
#  ('poor', 5),
#  ('madam', 5),
#  ('church', 5),
#  ('streets', 5),
#  ('beautiful', 5),
#  ('honour', 5),
#  ('waiting', 5),
#  ('moranzone', 5),
#  ('earth', 5),
#  ('neck', 5),
#  ('ground', 5),
#  ('list', 5),
#  ('eh', 5),
#  ('poulaphouca', 5),
#  ('hot', 5),
#  ('attack', 5),
#  ('tv', 5),
#  ('busy', 5),
#  ('nowhere', 5),
#  ('noise', 5),
#  ('liyah', 5),
#  ('preach', 5),
#  ('spears', 5),
#  ('houston', 5),
#  ('silbermond', 5),
#  ('gaga', 5),
#  ('acdc', 5),
#  ('cro', 5),
#  ('pnk', 5),
#  ('hosen', 5),
#  ('goulding', 5),
#  ('blunt', 5),
#  ('onkelz', 5),
#  ('daydreams', 5),
#  ('cupid', 5),
#  ('spine', 5),
#  ('common', 5),
#  ('shoes', 4),
#  ('constantly', 4),
#  ('able', 4),
#  ('past', 4),
#  ('sick', 4),
#  ('great', 4),
#  ('hungry', 4),
#  ('dumb', 4),
#  ('dude', 4),
#  ('gray', 4),
#  ('sure', 4),
#  ('effect', 4),
#  ('wall', 4),
#  ('brown', 4),
#  ('command', 4),
#  ('party', 4),
#  ('touch', 4),
#  ('joy', 4),
#  ('clear', 4),
#  ('indeed', 4),
#  ('bar', 4),
#  ('rhyme', 4),
#  ('doo', 4),
#  ('mission', 4),
#  ('attitude', 4),
#  ('mother', 4),
#  ('lose', 4),
#  ('yo', 4),
#  ('explain', 4),
#  ('sensitivity', 4),
#  ('passed', 4),
#  ('remember', 4),
#  ('spell', 4),
#  ('trouble', 4),
#  ('floor', 4),
#  ('steel', 4),
#  ('grip', 4),
#  ('race', 4),
#  ('candlelight', 4),
#  ('fantasies', 4),
#  ('company', 4),
#  ('state', 4),
#  ('ii', 4),
#  ('lennon', 4),
#  ('titanic', 4),
#  ('tears', 4),
#  ('france', 4),
#  ('p', 4),
#  ('oooh', 4),
#  ('eternity', 4),
#  ('near', 4),
#  ('deny', 4),
#  ('street', 4),
#  ('less', 4),
#  ('shy', 4),
#  ('amor', 4),
#  ('candle', 4),
#  ('born', 4),
#  ('scene', 4),
#  ('unpredictable', 4),
#  ('shoot', 4),
#  ('mercy', 4),
#  ('women', 4),
#  ('thanks', 4),
#  ('think', 4),
#  ('farewell', 4),
#  ('pass', 4),
#  ('drop', 4),
#  ('heard', 4),
#  ('answer', 4),
#  ('sin', 4),
#  ('live', 4),
#  ('anytime', 4),
#  ('blue', 4),
#  ('hee', 4),
#  ('hugging', 4),
#  ('win', 4),
#  ('says', 4),
#  ('tone', 4),
#  ('closet', 4),
#  ('land', 4),
#  ('molly', 4),
#  ('second', 4),
#  ('news', 4),
#  ('boots', 4),
#  ('done', 4),
#  ('thinking', 4),
#  ('white', 4),
#  ('memory', 4),
#  ('jams', 4),
#  ('creeping', 4),
#  ('dre', 4),
#  ('shaka', 4),
#  ('soon', 4),
#  ('gonna', 4),
#  ('understanding', 4),
#  ('teach', 4),
#  ('creep', 4),
#  ('truck', 4),
#  ('flavor', 4),
#  ('track', 4),
#  ('boo', 4),
#  ('vier', 4),
#  ('adams', 4),
#  ('collins', 4),
#  ('karl', 4),
#  ('abba', 4),
#  ('casper', 4),
#  ('onerepublic', 4),
#  ('perry', 4),
#  ('beyonc', 4),
#  ('santiano', 4),
#  ('paul', 4),
#  ('stiller', 4),
#  ('deichkind', 4),
#  ('madonna', 4),
#  ('akon', 4),
#  ('u', 4),
#  ('machine', 4),
#  ('beatles', 4),
#  ('dragons', 4),
#  ('freunde', 4),
#  ('blacc', 4),
#  ('bastille', 4),
#  ('aguilera', 4),
#  ('revolverheld', 4),
#  ('loaf', 4),
#  ('adele', 4),
#  ('names', 4),
#  ('twice', 4),
#  ('date', 4),
#  ('miss', 4),
#  ('indefinitely', 4),
#  ('wetter', 4),
#  ('breathing', 4),
#  ('meth', 4),
#  ('physics', 4),
#  ('tucked', 4),
#  ('shooting', 4),
#  ('demonic', 4),
#  ('bussing', 4),
#  ('nah', 4),
#  ('bastard', 4),
#  ('opponents', 4),
#  ('smoke', 4),
#  ('toys', 4),
#  ('piston', 4),
#  ('cock', 4),
#  ('cochran', 4),
#  ('range', 4),
#  ('group', 4),
#  ('useful', 4),
#  ('marijuana', 4),
#  ('drama', 4),
#  ('ruckus', 4),
#  ('writtens', 4),
#  ('heat', 4),
#  ('suicide', 4),
#  ('asshole', 4),
#  ('sucked', 4),
#  ('lick', 4),
#  ('twin', 4),
#  ('sec', 4),
#  ('gang', 4),
#  ('percs', 4),
#  ('adlibs', 4),
#  ('highway', 4),
#  ('jabbing', 4),
#  ('condo', 4),
#  ('bands', 4),
#  ('mortgage', 4),
#  ('remorse', 4),
#  ('write', 4),
#  ('penny', 4),
#  ('lunch', 4),
#  ('mj', 4),
#  ('belated', 4),
#  ('famous', 4),
#  ('hilfiger', 4),
#  ('nina', 4),
#  ('blowout', 4),
#  ('prime', 4),
#  ('coma', 4),
#  ('shaking', 4),
#  ('children', 3),
#  ('knees', 3),
#  ('guarantee', 3),
#  ('first', 3),
#  ('rock', 3),
#  ('anyway', 3),
#  ('jake', 3),
#  ('ow', 3),
#  ('red', 3),
#  ('scared', 3),
#  ('years', 3),
#  ('planet', 3),
#  ('satisfied', 3),
#  ('step', 3),
#  ('eye', 3),
#  ('secret', 3),
#  ('feelings', 3),
#  ('key', 3),
#  ('mood', 3),
#  ('mm', 3),
#  ('bright', 3),
#  ('flight', 3),
#  ('wings', 3),
#  ('pure', 3),
#  ('uhhuh', 3),
#  ('hoo', 3),
#  ('hoes', 3),
#  ('rest', 3),
#  ('known', 3),
#  ('space', 3),
#  ('kicking', 3),
#  ('clue', 3),
#  ('pants', 3),
#  ('learn', 3),
#  ('mic', 3),
#  ('talking', 3),
#  ('mmm', 3),
#  ('needed', 3),
#  ('nights', 3),
#  ('band', 3),
#  ('bone', 3),
#  ('sexy', 3),
#  ('bones', 3),
#  ('alibis', 3),
#  ('light', 3),
#  ('madness', 3),
#  ('west', 3),
#  ('mess', 3),
#  ('funky', 3),
#  ('bridge', 3),
#  ('part', 3),
#  ('program', 3),
#  ('guy', 3),
#  ('serious', 3),
#  ('decide', 3),
#  ('magic', 3),
#  ('funny', 3),
#  ('year', 3),
#  ('weather', 3),
#  ('toe', 3),
#  ('forget', 3),
#  ('happen', 3),
#  ('worst', 3),
#  ('groove', 3),
#  ('hardcore', 3),
#  ('bull', 3),
#  ('marriage', 3),
#  ('disaster', 3),
#  ('virginia', 3),
#  ('project', 3),
#  ('son', 3),
#  ('square', 3),
#  ('moon', 3),
#  ('front', 3),
#  ("'s", 3),
#  ('j', 3),
#  ('depression', 3),
#  ('k', 3),
#  ('hanging', 3),
#  ('chicago', 3),
#  ('others', 3),
#  ('hurts', 3),
#  ('ohoh', 3),
#  ('none', 3),
#  ('sky', 3),
#  ('mix', 3),
#  ('set', 3),
#  ('always', 3),
#  ('intimate', 3),
#  ('get', 3),
#  ('family', 3),
#  ('bye', 3),
#  ('james', 3),
#  ('gentlemen', 3),
#  ('water', 3),
#  ('taxes', 3),
#  ('poverty', 3),
#  ('orvieto', 3),
#  ('matter', 3),
#  ('reasons', 3),
#  ('father', 3),
#  ('court', 3),
#  ('main', 3),
#  ('tongue', 3),
#  ('lips', 3),
#  ('would', 3),
#  ('age', 3),
#  ('rich', 3),
#  ('throat', 3),
#  ('sinful', 3),
#  ('since', 3),
#  ('crying', 3),
#  ('faces', 3),
#  ('daddy', 3),
#  ('uhuh', 3),
#  ('pay', 3),
#  ('living', 3),
#  ('six', 3),
#  ('tat', 3),
#  ('surprise', 3),
#  ('bugging', 3),
#  ('rocks', 3),
#  ('belly', 3),
#  ('stick', 3),
#  ('run', 3),
#  ('worlds', 3),
#  ('flirt', 3),
#  ('quiet', 3),
#  ('fact', 3),
#  ('pound', 3),
#  ('cuckoo', 3),
#  ('hear', 3),
#  ('minims', 3),
#  ('keys', 3),
#  ('miracle', 3),
#  ('shillings', 3),
#  ('zoe', 3),
#  ('summer', 3),
#  ('sound', 3),
#  ('clever', 3),
#  ('funeral', 3),
#  ('spittoon', 3),
#  ('habit', 3),
#  ('ago', 3),
#  ('waterfall', 3),
#  ('shade', 3),
#  ('cream', 3),
#  ('corner', 3),
#  ('whore', 3),
#  ('private', 3),
#  ('bleeding', 3),
#  ('called', 3),
#  ('spend', 3),
#  ('ooohhh', 3),
#  ('lyin', 3),
#  ('coming', 3),
#  ('hi', 3),
#  ('satisfaction', 3),
#  ('heyho', 3),
#  ('heyhoheyho', 3),
#  ('missing', 3),
#  ('kitten', 3),
#  ('stuff', 3),
#  ('episode', 3),
#  ('attention', 3),
#  ('slipping', 3),
#  ('closer', 3),
#  ('hahaha', 3),
#  ('team', 3),
#  ('wishes', 3),
#  ('misses', 3),
#  ('crime', 3),
#  ('played', 3),
#  ('hood', 3),
#  ('letters', 3),
#  ('edge', 3),
#  ('skillz', 3),
#  ('benny', 3),
#  ('clips', 3),
#  ('told', 3),
#  ('glove', 3),
#  ('nothin', 3),
#  ('wiz', 3),
#  ('socks', 3),
#  ('chanel', 3),
#  ('candela', 3),
#  ('newman', 3),
#  ('balls', 3),
#  ('bendzko', 3),
#  ('pitbull', 3),
#  ('poisel', 3),
#  ('sia', 3),
#  ('krause', 3),
#  ('garvey', 3),
#  ('schuhmacher', 3),
#  ('cyrus', 3),
#  ('rey', 3),
#  ('sons', 3),
#  ('stones', 3),
#  ('mllerwesternhagen', 3),
#  ('floyd', 3),
#  ('ich', 3),
#  ('berg', 3),
#  ('jones', 3),
#  ('birdy', 3),
#  ('rida', 3),
#  ('grnemeyer', 3),
#  ('bosse', 3),
#  ('united', 3),
#  ('fischer', 3),
#  ('lokalpiloten', 3),
#  ('existent', 3),
#  ('derulo', 3),
#  ('naked', 3),
#  ('naughty', 3),
#  ('course', 3),
#  ('hung', 3),
#  ('cut', 3),
#  ('shower', 3),
#  ('uhh', 3),
#  ('shorty', 3),
#  ('fronting', 3),
#  ('pavement', 3),
#  ('lately', 3),
#  ('curb', 3),
#  ('cars', 3),
#  ('straight', 3),
#  ('jet', 3),
#  ('sister', 3),
#  ('shine', 3),
#  ('seeking', 3),
#  ('jeans', 3),
#  ('big', 3),
#  ('hearted', 2),
#  ('precious', 2),
#  ('cards', 2),
#  ('happening', 2),
#  ('lasting', 2),
#  ('candy', 2),
#  ('spoon', 2),
#  ('prosperity', 2),
#  ('idea', 2),
#  ('half', 2),
#  ('exit', 2),
#  ('pb', 2),
#  ('blood', 2),
#  ('emerald', 2),
#  ('ruby', 2),
#  ('whoops', 2),
#  ('green', 2),
#  ('trying', 2),
#  ('along', 2),
#  ('ohhhhhhh', 2),
#  ('bite', 2),
#  ('somehow', 2),
#  ('mad', 2),
#  ('sad', 2),
#  ('calm', 2),
#  ('ease', 2),
#  ('journey', 2),
#  ('forevermore', 2),
#  ('dreaming', 2),
#  ('mike', 2),
#  ('darlin', 2),
#  ('caress', 2),
#  ('coat', 2),
#  ('ohohoh', 2),
#  ('within', 2),
#  ('faith', 2),
#  ('mississippi', 2),
#  ('wayne', 2),
#  ('seat', 2),
#  ('rhythm', 2),
#  ('quit', 2),
#  ('rump', 2),
#  ('bump', 2),
#  ('hammer', 2),
#  ('oooooooooh', 2),
#  ('feels', 2),
#  ('deal', 2),
#  ('wee', 2),
#  ('reality', 2),
#  ('call', 2),
#  ('believed', 2),
#  ('eventually', 2),
#  ('lawd', 2),
#  ('possible', 2),
#  ('woah', 2),
#  ('victim', 2),
#  ('east', 2),
#  ('moves', 2),
#  ('eat', 2),
#  ('kick', 2),
#  ('art', 2),
#  ('trip', 2),
#  ('tough', 2),
#  ('lip', 2),
#  ('bachelor', 2),
#  ('bbd', 2),
#  ('everyday', 2),
#  ('wiiiiild', 2),
#  ('pearls', 2),
#  ('wealth', 2),
#  ('fatal', 2),
#  ('angel', 2),
#  ('cares', 2),
#  ('hug', 2),
#  ('anymore', 2),
#  ('began', 2),
#  ('fast', 2),
#  ('intentions', 2),
#  ('wondering', 2),
#  ('believe', 2),
#  ('whole', 2),
#  ('came', 2),
#  ('evening', 2),
#  ('section', 2),
#  ('jack', 2),
#  ('sermon', 2),
#  ('safe', 2),
#  ('locked', 2),
#  ('seems', 2),
#  ("d'wayne", 2),
#  ('wales', 2),
#  ('event', 2),
#  ('america', 2),
#  ('legend', 2),
#  ('riot', 2),
#  ('pamphlet', 2),
#  ('riots', 2),
#  ('revolution', 2),
#  ('viii', 2),
#  ('atlantic', 2),
#  ('insane', 2),
#  ('britain', 2),
#  ('plague', 2),
#  ('bomb', 2),
#  ('russia', 2),
#  ('assassination', 2),
#  ('england', 2),
#  ('stand', 2),
#  ('luddites', 2),
#  ('storm', 2),
#  ('ww', 2),
#  ('holocaust', 2),
#  ('ad', 2),
#  ('present', 2),
#  ('york', 2),
#  ('affair', 2),
#  ('slaves', 2),
#  ('hamilton', 2),
#  ('ireland', 2),
#  ('victims', 2),
#  ('v', 2),
#  ('duel', 2),
#  ('killed', 2),
#  ('massacre', 2),
#  ('bare', 2),
#  ...]

# %%
token_1990s_str = " ".join(filter_1990s_token)#the wordcloud module takes in a string hence the need for 

wordcloud = WordCloud(colormap="Blues").generate(token_1990s_str)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
token_2000s_str = " ".join(filter_2000s_token)#the wordcloud module takes in a string hence the need for 

wordcloud = WordCloud(colormap="Blues").generate(token_2000s_str)

plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
frequency_analysis(filter_1990s_token)
# Out:
# baby	418
# love	245
# yeah	242
# time	134
# know	130
# go	105
# girl	105
# way	87
# night	81
# babe	78
# tonight	78
# alone	77
# shit	77
# back	74
# right	70
# heart	68
# oh	67
# day	67
# duchess	67
# crazy	65

# %%
frequency_analysis(filter_2000s_token)
# Out:
# yeah	204
# baby	178
# oh	114
# girl	101
# one	96
# life	95
# love	88
# back	82
# time	80
# ya	80
# right	66
# name	63
# go	62
# us	59
# shit	56
# know	55
# thing	51
# mind	49
# diamond	49
# tonight	48

# %%
most_comm_1990s = filter_1990s_token_fql.most_common(50)
most_comm_2000s = filter_2000s_token_fql.most_common(50)

# %%
common = [tk for tk in most_comm_1990s if tk[0] in most_comm_2000s]  #check the coomon words in tokens for both years

# %%
common
# Out:
# []

# %%
# from nltk.stem.wordnet import WordNetLemmatizer
# nltk.download('wordnet')
# lemma = WordNetLemmatizer()

# %%
# lemmatized_90s = [lemma.lemmatize(word) for word in filter_1990s_token]

# %%
# lemmatized_90s

# %%
# filter_1990s_token

# %%
# data.plot('artist', type="bar")
# data.groupby('year').sum().plot(y='artist', kind='bar')
# data[data.year >= 2014].groupby([data.artist, 'artist']).count().plot(kind='bar', figsize=(20, 10))
# plt.figure(figsize=(15, 10))

# %%
#doc is a Counter representing an fql from a document.
from math import log

def tf(term, doc):
    return doc[term] / sum(doc.values()) #term freq / total terms (relative term freq)

def num_containing(term, corpus):
    return sum(1 for doc in corpus if term in doc) #counts docs in corpus containing term.

#1 added to numerator and denominator is for preventing division by zero. Equivalent of an extra document containing all terms once.
def idf(term, corpus):
    n_t = num_containing(term,corpus)
    return log((len(corpus)+1) / ((n_t) + 1))
    
def tfidf(term, doc, corpus):
    return tf(term, doc) * idf(term, corpus)

# %%
corpus_fqls = [song.token_fql for song in music_library]
for song in music_library:
    print(song.artist, song.song, song.year)
    scores = {term: tfidf(term, song.token_fql, corpus_fqls) for term in song.token_fql}
    sorted_terms = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    for term, score in sorted_terms[:5]:
        print("\tToken: {}, TF-IDF: {}".format(term, round(score, 5)))
    print("\n")
# Out:
# Babyface Tender Lover 1990
# 	Token: lover, TF-IDF: 0.26189
# 	Token: love, TF-IDF: 0.23942
# 	Token: limit, TF-IDF: 0.17819
# 	Token: give, TF-IDF: 0.15299
# 	Token: try, TF-IDF: 0.12778
#
#
# Janet Jackson Rhythm Nation 1990
# 	Token: nation, TF-IDF: 0.93084
# 	Token: unite, TF-IDF: 0.46542
# 	Token: bass, TF-IDF: 0.46205
# 	Token: today, TF-IDF: 0.28301
# 	Token: life, TF-IDF: 0.25393
#
#
# Quincy Jones Featuring Ray Charles & Chaka Khan I'll Be Good To You 1990
# 	Token: lie, TF-IDF: 0.17566
# 	Token: cry, TF-IDF: 0.15164
# 	Token: knowhow, TF-IDF: 0.12941
# 	Token: express, TF-IDF: 0.12941
# 	Token: long, TF-IDF: 0.12672
#
#
# Regina Belle Make It Like It Was 1990
# 	Token: was, TF-IDF: 0.95997
# 	Token: constantly, TF-IDF: 0.35002
# 	Token: able, TF-IDF: 0.35002
# 	Token: be, TF-IDF: 0.17524
# 	Token: empty, TF-IDF: 0.12633
#
#
# Skyy Real Love 1990
# 	Token: feel, TF-IDF: 0.40802
# 	Token: boy, TF-IDF: 0.19358
# 	Token: baby, TF-IDF: 0.16558
# 	Token: afraid, TF-IDF: 0.15294
# 	Token: love, TF-IDF: 0.14907
#
#
# Ruby Turner It's Gonna Be Alright 1990
# 	Token: finn, TF-IDF: 0.19947
# 	Token: jake, TF-IDF: 0.11968
# 	Token: hungry, TF-IDF: 0.11053
# 	Token: spoon, TF-IDF: 0.07979
# 	Token: prosperity, TF-IDF: 0.07979
#
#
# Stacy Lattisaw & Johnny Gill Where Do We Go From Here 1990
# 	Token: step, TF-IDF: 0.23655
# 	Token: away, TF-IDF: 0.22259
# 	Token: trying, TF-IDF: 0.21575
# 	Token: love, TF-IDF: 0.20259
# 	Token: baby, TF-IDF: 0.15001
#
#
# Janet Jackson Escapade 1990
# 	Token: escapade, TF-IDF: 1.15343
# 	Token: made, TF-IDF: 0.36584
# 	Token: day, TF-IDF: 0.231
# 	Token: away, TF-IDF: 0.18872
# 	Token: week, TF-IDF: 0.17041
#
#
# Quincy Jones The Secret Garden 1990
# 	Token: garden, TF-IDF: 0.25987
# 	Token: ohhhhhhh, TF-IDF: 0.14946
# 	Token: secret, TF-IDF: 0.12993
# 	Token: right, TF-IDF: 0.12958
# 	Token: alive, TF-IDF: 0.09464
#
#
# Lisa Stansfield All Around The World 1990
# 	Token: him, TF-IDF: 0.18902
# 	Token: hearted, TF-IDF: 0.16898
# 	Token: baby, TF-IDF: 0.16811
# 	Token: i, TF-IDF: 0.16106
# 	Token: mm, TF-IDF: 0.15906
#
#
# Troop Spread My Wings 1990
# 	Token: free, TF-IDF: 0.35332
# 	Token: ease, TF-IDF: 0.31211
# 	Token: calm, TF-IDF: 0.28825
# 	Token: flight, TF-IDF: 0.27133
# 	Token: bright, TF-IDF: 0.23841
#
#
# After 7 Ready Or Not 1990
# 	Token: for, TF-IDF: 0.37998
# 	Token: more, TF-IDF: 0.31607
# 	Token: not, TF-IDF: 0.28634
# 	Token: forevermore, TF-IDF: 0.26529
# 	Token: mountains, TF-IDF: 0.13264
#
#
# Bell Biv DeVoe Poison 1990
# 	Token: poison, TF-IDF: 1.36664
# 	Token: effect, TF-IDF: 0.13978
# 	Token: her, TF-IDF: 0.12287
# 	Token: mind, TF-IDF: 0.11443
# 	Token: find, TF-IDF: 0.10406
#
#
# Johnny Gill Rub You The Right Way 1990
# 	Token: tenderness, TF-IDF: 0.43695
# 	Token: hands, TF-IDF: 0.3232
# 	Token: bass, TF-IDF: 0.30985
# 	Token: way, TF-IDF: 0.28383
# 	Token: hey, TF-IDF: 0.15088
#
#
# En Vogue Hold On 1990
# 	Token: love, TF-IDF: 0.22992
# 	Token: despair, TF-IDF: 0.21965
# 	Token: on, TF-IDF: 0.14172
# 	Token: ooh, TF-IDF: 0.12532
# 	Token: soul, TF-IDF: 0.10447
#
#
# Tony Toni Tone The Blues 1990
# 	Token: blues, TF-IDF: 1.01634
# 	Token: wayne, TF-IDF: 0.1488
# 	Token: hands, TF-IDF: 0.11641
# 	Token: you, TF-IDF: 0.10767
# 	Token: hihat, TF-IDF: 0.08993
#
#
# M.C. Hammer U Can't Touch This 1990
# 	Token: this, TF-IDF: 0.43127
# 	Token: touch, TF-IDF: 0.14392
# 	Token: down, TF-IDF: 0.10441
# 	Token: oaktown, TF-IDF: 0.08698
# 	Token: such, TF-IDF: 0.08698
#
#
# Troop All I Do Is Think Of You 1990
# 	Token: mind, TF-IDF: 0.20411
# 	Token: ooooooooooooh, TF-IDF: 0.1434
# 	Token: ooooooh, TF-IDF: 0.1434
# 	Token: about, TF-IDF: 0.14042
# 	Token: oooooooooh, TF-IDF: 0.13244
#
#
# Lisa Stansfield You Can't Deny It 1990
# 	Token: out, TF-IDF: 0.4089
# 	Token: crazy, TF-IDF: 0.25063
# 	Token: games, TF-IDF: 0.20902
# 	Token: lovers, TF-IDF: 0.20034
# 	Token: baby, TF-IDF: 0.18572
#
#
# Johnny Gill My, My, My 1990
# 	Token: my, TF-IDF: 0.78319
# 	Token: tonight, TF-IDF: 0.24316
# 	Token: heels, TF-IDF: 0.09308
# 	Token: bedroom, TF-IDF: 0.09308
# 	Token: sweet, TF-IDF: 0.07111
#
#
# Keith Sweat Make You Sweat 1990
# 	Token: sweat, TF-IDF: 0.74715
# 	Token: yes, TF-IDF: 0.61781
# 	Token: girl, TF-IDF: 0.19425
# 	Token: baby, TF-IDF: 0.16597
# 	Token: lights, TF-IDF: 0.08951
#
#
# After 7 Can't Stop 1990
# 	Token: feel, TF-IDF: 0.32765
# 	Token: we, TF-IDF: 0.17281
# 	Token: mmm, TF-IDF: 0.13978
# 	Token: difference, TF-IDF: 0.12749
# 	Token: clear, TF-IDF: 0.12282
#
#
# Mariah Carey Vision Of Love 1990
# 	Token: believed, TF-IDF: 0.26529
# 	Token: needed, TF-IDF: 0.24502
# 	Token: eventually, TF-IDF: 0.24502
# 	Token: kind, TF-IDF: 0.21947
# 	Token: nights, TF-IDF: 0.21947
#
#
# The Time Jerk Out 1990
# 	Token: sight, TF-IDF: 0.32662
# 	Token: out, TF-IDF: 0.26834
# 	Token: the, TF-IDF: 0.21462
# 	Token: tonight, TF-IDF: 0.17646
# 	Token: nice, TF-IDF: 0.07701
#
#
# Tony Toni Tone Feels Good 1990
# 	Token: good, TF-IDF: 0.50489
# 	Token: doo, TF-IDF: 0.27925
# 	Token: baby, TF-IDF: 0.15396
# 	Token: feet, TF-IDF: 0.13263
# 	Token: bones, TF-IDF: 0.12896
#
#
# En Vogue Lies 1990
# 	Token: disguise, TF-IDF: 0.69206
# 	Token: alibis, TF-IDF: 0.31959
# 	Token: lies, TF-IDF: 0.27438
# 	Token: victim, TF-IDF: 0.21306
# 	Token: minds, TF-IDF: 0.11534
#
#
# The Boys Crazy 1990
# 	Token: crazy, TF-IDF: 0.73341
# 	Token: going, TF-IDF: 0.4651
# 	Token: baby, TF-IDF: 0.08791
# 	Token: east, TF-IDF: 0.08698
# 	Token: bridge, TF-IDF: 0.08033
#
#
# Prince Thieves In The Temple 1990
# 	Token: temple, TF-IDF: 0.73692
# 	Token: tonight, TF-IDF: 0.51335
# 	Token: hurry, TF-IDF: 0.38439
# 	Token: quick, TF-IDF: 0.31681
# 	Token: kick, TF-IDF: 0.13612
#
#
# Pebbles Giving You The Benefit 1990
# 	Token: benefit, TF-IDF: 0.44964
# 	Token: out, TF-IDF: 0.18712
# 	Token: trip, TF-IDF: 0.15636
# 	Token: doubt, TF-IDF: 0.12887
# 	Token: hard, TF-IDF: 0.12207
#
#
# Samuelle So You Like What You See 1990
# 	Token: program, TF-IDF: 0.81672
# 	Token: afar, TF-IDF: 0.29477
# 	Token: awhile, TF-IDF: 0.29477
# 	Token: forcefully, TF-IDF: 0.29477
# 	Token: intermission, TF-IDF: 0.29477
#
#
# Mariah Carey Love Takes Time 1990
# 	Token: much, TF-IDF: 0.30943
# 	Token: inside, TF-IDF: 0.26665
# 	Token: time, TF-IDF: 0.2154
# 	Token: here, TF-IDF: 0.17134
# 	Token: alone, TF-IDF: 0.17134
#
#
# Bell Biv DeVoe B.B.D. (I Thought It Was Me)? 1990
# 	Token: guys, TF-IDF: 0.40462
# 	Token: wild, TF-IDF: 0.18953
# 	Token: bbd, TF-IDF: 0.18617
# 	Token: wiiiiild, TF-IDF: 0.18617
# 	Token: everyday, TF-IDF: 0.17194
#
#
# Al B. Sure! Missunderstanding 1990
# 	Token: demanding, TF-IDF: 0.3817
# 	Token: apart, TF-IDF: 0.31313
# 	Token: self, TF-IDF: 0.21306
# 	Token: pearls, TF-IDF: 0.21306
# 	Token: heart, TF-IDF: 0.19459
#
#
# Whitney Houston I'm Your Baby Tonight 1990
# 	Token: tonight, TF-IDF: 0.44235
# 	Token: fantasy, TF-IDF: 0.29188
# 	Token: ecstasy, TF-IDF: 0.26816
# 	Token: everything, TF-IDF: 0.22001
# 	Token: fatal, TF-IDF: 0.11289
#
#
# Ralph Tresvant Sensitivity 1990
# 	Token: sensitivity, TF-IDF: 0.41614
# 	Token: funny, TF-IDF: 0.31211
# 	Token: give, TF-IDF: 0.24748
# 	Token: honey, TF-IDF: 0.23841
# 	Token: money, TF-IDF: 0.16593
#
#
# Tony Toni Tone It Never Rains (In Southern California) 1990
# 	Token: california, TF-IDF: 1.4363
# 	Token: coast, TF-IDF: 0.4574
# 	Token: rains, TF-IDF: 0.4574
# 	Token: there, TF-IDF: 0.11339
# 	Token: guy, TF-IDF: 0.07568
#
#
# Freddie Jackson Love Me Down 1991
# 	Token: toe, TF-IDF: 0.26094
# 	Token: more, TF-IDF: 0.2418
# 	Token: down, TF-IDF: 0.23492
# 	Token: moment, TF-IDF: 0.21588
# 	Token: slow, TF-IDF: 0.1453
#
#
# Surface The First Time 1991
# 	Token: regrets, TF-IDF: 0.17115
# 	Token: eyes, TF-IDF: 0.16978
# 	Token: cried, TF-IDF: 0.15807
# 	Token: forget, TF-IDF: 0.14879
# 	Token: passed, TF-IDF: 0.1416
#
#
# Pebbles Love Makes Things Happen 1991
# 	Token: know, TF-IDF: 0.41836
# 	Token: never, TF-IDF: 0.23564
# 	Token: spell, TF-IDF: 0.17094
# 	Token: no, TF-IDF: 0.12493
# 	Token: happen, TF-IDF: 0.11396
#
#
# En Vogue You Don't Have To Worry 1991
# 	Token: thang, TF-IDF: 1.2339
# 	Token: shame, TF-IDF: 0.91151
# 	Token: wondering, TF-IDF: 0.22792
# 	Token: dishonesty, TF-IDF: 0.12339
# 	Token: dismay, TF-IDF: 0.12339
#
#
# Keith Sweat I'll Give All My Love To You 1991
# 	Token: running, TF-IDF: 0.22143
# 	Token: baby, TF-IDF: 0.18817
# 	Token: will, TF-IDF: 0.16361
# 	Token: darling, TF-IDF: 0.12635
# 	Token: you, TF-IDF: 0.11145
#
#
# C+C Music Factory Gonna Make You Sweat (Everybody Dance Now) 1991
# 	Token: now, TF-IDF: 0.33629
# 	Token: control, TF-IDF: 0.23395
# 	Token: music, TF-IDF: 0.1706
# 	Token: sweat, TF-IDF: 0.13506
# 	Token: move, TF-IDF: 0.10812
#
#
# Whitney Houston All The Man That I Need 1991
# 	Token: seen, TF-IDF: 0.4632
# 	Token: got, TF-IDF: 0.42244
# 	Token: world, TF-IDF: 0.28951
# 	Token: need, TF-IDF: 0.27927
# 	Token: up, TF-IDF: 0.17786
#
#
# The Rude Boys Written All Over Your Face 1991
# 	Token: jack, TF-IDF: 0.27209
# 	Token: locked, TF-IDF: 0.2513
# 	Token: grip, TF-IDF: 0.2251
# 	Token: houdini, TF-IDF: 0.13605
# 	Token: wrecking, TF-IDF: 0.13605
#
#
# Hi-Five I Like The Way (The Kissing Game) 1991
# 	Token: way, TF-IDF: 0.3093
# 	Token: game, TF-IDF: 0.25905
# 	Token: day, TF-IDF: 0.24597
# 	Token: good, TF-IDF: 0.1142
# 	Token: seems, TF-IDF: 0.0961
#
#
# Freddie Jackson Do Me Again 1991
# 	Token: candlelight, TF-IDF: 0.44548
# 	Token: fantasies, TF-IDF: 0.41933
# 	Token: night, TF-IDF: 0.22304
# 	Token: yes, TF-IDF: 0.19554
# 	Token: need, TF-IDF: 0.1481
#
#
# Johnny Gill Wrap My Body Tight 1991
# 	Token: tight, TF-IDF: 0.20646
# 	Token: body, TF-IDF: 0.12845
# 	Token: ooh, TF-IDF: 0.11442
# 	Token: tonight, TF-IDF: 0.10044
# 	Token: lights, TF-IDF: 0.09146
#
#
# Tony Toni Tone Whatever You Want 1991
# 	Token: provide, TF-IDF: 1.10652
# 	Token: want, TF-IDF: 0.42211
# 	Token: d'wayne, TF-IDF: 0.17115
# 	Token: need, TF-IDF: 0.15765
# 	Token: things, TF-IDF: 0.13855
#
#
# Christopher Williams I'm Dreamin' (From "New Jack City") 1991
# 	Token: war, TF-IDF: 0.19154
# 	Token: titanic, TF-IDF: 0.07718
# 	Token: disaster, TF-IDF: 0.05346
# 	Token: chair, TF-IDF: 0.05032
# 	Token: wall, TF-IDF: 0.05032
#
#
# Phil Perry Call Me 1991
# 	Token: baby, TF-IDF: 0.18872
# 	Token: babay, TF-IDF: 0.17115
# 	Token: too, TF-IDF: 0.15407
# 	Token: part, TF-IDF: 0.14879
# 	Token: moment, TF-IDF: 0.1416
#
#
# Teddy Pendergrass It Should've Been You 1991
# 	Token: whoa, TF-IDF: 0.13871
# 	Token: be, TF-IDF: 0.12106
# 	Token: see, TF-IDF: 0.11657
# 	Token: eternity, TF-IDF: 0.11551
# 	Token: hurts, TF-IDF: 0.11072
#
#
# Keith Washington Kissing You 1991
# 	Token: ohoh, TF-IDF: 0.29402
# 	Token: believes, TF-IDF: 0.19601
# 	Token: share, TF-IDF: 0.14056
# 	Token: dream, TF-IDF: 0.14056
# 	Token: night, TF-IDF: 0.1104
#
#
# Color Me Badd I Wanna Sex You Up (From "New Jack City") 1991
#
#
# Luther Vandross Power Of Love/Love Power 1991
# 	Token: power, TF-IDF: 0.25446
# 	Token: love, TF-IDF: 0.24809
# 	Token: none, TF-IDF: 0.19085
# 	Token: deny, TF-IDF: 0.12195
# 	Token: hide, TF-IDF: 0.11748
#
#
# Lisa Fischer How Can I Ease The Pain 1991
# 	Token: pain, TF-IDF: 0.79864
# 	Token: again, TF-IDF: 0.33201
# 	Token: heart, TF-IDF: 0.30515
# 	Token: imasu, TF-IDF: 0.12059
# 	Token: refuse, TF-IDF: 0.12059
#
#
# Damian Dame Exclusivity 1991
# 	Token: exclusivity, TF-IDF: 0.717
# 	Token: exclusively, TF-IDF: 0.3585
# 	Token: want, TF-IDF: 0.23578
# 	Token: need, TF-IDF: 0.09906
# 	Token: yo, TF-IDF: 0.09497
#
#
# Levert Baby I'm Ready 1991
# 	Token: bit, TF-IDF: 0.37397
# 	Token: games, TF-IDF: 0.29263
# 	Token: ready, TF-IDF: 0.14933
# 	Token: love, TF-IDF: 0.14631
# 	Token: chance, TF-IDF: 0.13816
#
#
# D.J. Jazzy Jeff & The Fresh Prince Summertime 1991
# 	Token: summertime, TF-IDF: 0.51346
# 	Token: unwind, TF-IDF: 0.31615
# 	Token: madness, TF-IDF: 0.14879
# 	Token: rhyme, TF-IDF: 0.1416
# 	Token: transformed, TF-IDF: 0.08558
#
#
# Hi-Five I Can't Wait Another Minute 1991
# 	Token: minute, TF-IDF: 0.38768
# 	Token: tonight, TF-IDF: 0.1777
# 	Token: no, TF-IDF: 0.16529
# 	Token: well, TF-IDF: 0.13515
# 	Token: away, TF-IDF: 0.12521
#
#
# Peabo Bryson Can You Stop The Rain 1991
# 	Token: falling, TF-IDF: 0.45222
# 	Token: stop, TF-IDF: 0.16123
# 	Token: rain, TF-IDF: 0.15371
# 	Token: away, TF-IDF: 0.12766
# 	Token: again, TF-IDF: 0.12276
#
#
# BeBe & CeCe Winans Addictive Love 1991
# 	Token: crazy, TF-IDF: 0.12146
# 	Token: yeah, TF-IDF: 0.1043
# 	Token: more, TF-IDF: 0.09725
# 	Token: everything, TF-IDF: 0.09091
# 	Token: christ, TF-IDF: 0.08163
#
#
# Lisa Lisa And Cult Jam Let The Beat Hit 'Em 1991
# 	Token: them, TF-IDF: 0.39475
# 	Token: round, TF-IDF: 0.31554
# 	Token: control, TF-IDF: 0.28513
# 	Token: let, TF-IDF: 0.24502
# 	Token: and, TF-IDF: 0.21476
#
#
# Phyllis Hyman Don't Wanna Change The World 1991
# 	Token: girl, TF-IDF: 0.29889
# 	Token: world, TF-IDF: 0.22618
# 	Token: ambition, TF-IDF: 0.18949
# 	Token: mission, TF-IDF: 0.16474
# 	Token: affection, TF-IDF: 0.14475
#
#
# Color Me Badd I Adore Mi Amor 1991
# 	Token: amor, TF-IDF: 0.54418
# 	Token: stay, TF-IDF: 0.24818
# 	Token: forever, TF-IDF: 0.22026
# 	Token: away, TF-IDF: 0.16695
# 	Token: place, TF-IDF: 0.14684
#
#
# Vanessa Williams Running Back To You 1991
# 	Token: running, TF-IDF: 0.41382
# 	Token: wanna, TF-IDF: 0.30298
# 	Token: back, TF-IDF: 0.28463
# 	Token: oh, TF-IDF: 0.18699
# 	Token: to, TF-IDF: 0.06909
#
#
# Karyn White Romantic 1991
# 	Token: romantic, TF-IDF: 1.32231
# 	Token: candle, TF-IDF: 0.33688
# 	Token: surrender, TF-IDF: 0.16844
# 	Token: moonlight, TF-IDF: 0.16844
# 	Token: romance, TF-IDF: 0.13935
#
#
# Boyz II Men It's So Hard To Say Goodbye To Yesterday 1991
# 	Token: yesterday, TF-IDF: 0.81061
# 	Token: rain, TF-IDF: 0.39195
# 	Token: memories, TF-IDF: 0.38017
# 	Token: lead, TF-IDF: 0.23063
# 	Token: road, TF-IDF: 0.21947
#
#
# Mariah Carey Emotions 1991
# 	Token: emotions, TF-IDF: 1.04262
# 	Token: above, TF-IDF: 0.44757
# 	Token: of, TF-IDF: 0.39684
# 	Token: tenderly, TF-IDF: 0.22578
# 	Token: dream, TF-IDF: 0.14953
#
#
# Jodeci Forever My Lady 1991
# 	Token: lady, TF-IDF: 0.31373
# 	Token: forever, TF-IDF: 0.16844
# 	Token: warm, TF-IDF: 0.16499
# 	Token: close, TF-IDF: 0.14495
# 	Token: dream, TF-IDF: 0.13781
#
#
# Tracie Spencer Tender Kisses 1991
# 	Token: kisses, TF-IDF: 0.29928
# 	Token: unpredictable, TF-IDF: 0.20967
# 	Token: confused, TF-IDF: 0.16802
# 	Token: own, TF-IDF: 0.15272
# 	Token: wanted, TF-IDF: 0.10483
#
#
# The Rude Boys Are You Lonely For Me 1991
# 	Token: duchess, TF-IDF: 0.42472
# 	Token: guido, TF-IDF: 0.31695
# 	Token: duke, TF-IDF: 0.26624
# 	Token: citizen, TF-IDF: 0.13946
# 	Token: beatrice, TF-IDF: 0.03803
#
#
# BeBe & CeCe Winans I'll Take You There 1991
# 	Token: now, TF-IDF: 0.30884
# 	Token: mercy, TF-IDF: 0.30002
# 	Token: faces, TF-IDF: 0.20001
# 	Token: there, TF-IDF: 0.17896
# 	Token: all, TF-IDF: 0.12193
#
#
# Gerald Levert Private Line 1991
# 	Token: line, TF-IDF: 0.5218
# 	Token: anytime, TF-IDF: 0.38434
# 	Token: back, TF-IDF: 0.27235
# 	Token: company, TF-IDF: 0.18089
# 	Token: serious, TF-IDF: 0.17214
#
#
# Shanice I Love Your Smile 1991
# 	Token: smile, TF-IDF: 0.33999
# 	Token: direction, TF-IDF: 0.15876
# 	Token: give, TF-IDF: 0.15876
# 	Token: world, TF-IDF: 0.14339
# 	Token: that, TF-IDF: 0.10156
#
#
# Shanice I Love Your Smile 1992
# 	Token: smile, TF-IDF: 0.33999
# 	Token: direction, TF-IDF: 0.15876
# 	Token: give, TF-IDF: 0.15876
# 	Token: world, TF-IDF: 0.14339
# 	Token: that, TF-IDF: 0.10156
#
#
# Tevin Campbell Tell Me What You Want Me To Do 1992
# 	Token: do, TF-IDF: 0.19351
# 	Token: girl, TF-IDF: 0.14491
# 	Token: knees, TF-IDF: 0.10017
# 	Token: somehow, TF-IDF: 0.10017
# 	Token: crying, TF-IDF: 0.0965
#
#
# Keith Sweat Keep It Comin' 1992
# 	Token: hugging, TF-IDF: 0.58953
# 	Token: loving, TF-IDF: 0.45034
# 	Token: crazy, TF-IDF: 0.2924
# 	Token: babe, TF-IDF: 0.2111
# 	Token: thrill, TF-IDF: 0.13612
#
#
# Jodeci Stay 1992
# 	Token: while, TF-IDF: 0.49496
# 	Token: stay, TF-IDF: 0.44283
# 	Token: friends, TF-IDF: 0.11777
# 	Token: lied, TF-IDF: 0.10404
# 	Token: sunrise, TF-IDF: 0.10404
#
#
# Boyz II Men Uhh Ahh 1992
# 	Token: ahh, TF-IDF: 1.09737
# 	Token: close, TF-IDF: 0.11551
# 	Token: follows, TF-IDF: 0.0829
# 	Token: extreme, TF-IDF: 0.0829
# 	Token: overflows, TF-IDF: 0.0829
#
#
# Michael Jackson Remember The Time 1992
# 	Token: time, TF-IDF: 0.33072
# 	Token: love, TF-IDF: 0.17956
# 	Token: tat, TF-IDF: 0.14849
# 	Token: girl, TF-IDF: 0.11527
# 	Token: said, TF-IDF: 0.0942
#
#
# Prince And The N.P.G. Diamonds And Pearls 1992
#
#
# Vanessa Williams Save The Best For Last 1992
# 	Token: last, TF-IDF: 0.48994
# 	Token: passed, TF-IDF: 0.41152
# 	Token: june, TF-IDF: 0.30627
# 	Token: moon, TF-IDF: 0.28829
# 	Token: place, TF-IDF: 0.17897
#
#
# Glenn Jones Here I Go Again 1992
# 	Token: again, TF-IDF: 0.3913
# 	Token: because, TF-IDF: 0.23761
# 	Token: heartaches, TF-IDF: 0.16581
# 	Token: love, TF-IDF: 0.1646
# 	Token: mistakes, TF-IDF: 0.14415
#
#
# Aaron Hall Don't Be Afraid 1992
# 	Token: afraid, TF-IDF: 1.24709
# 	Token: baby, TF-IDF: 0.12001
# 	Token: a, TF-IDF: 0.10566
# 	Token: alright, TF-IDF: 0.09565
# 	Token: wake, TF-IDF: 0.08163
#
#
# Lisa Stansfield All Woman 1992
# 	Token: woman, TF-IDF: 0.52805
# 	Token: lady, TF-IDF: 0.38096
# 	Token: strong, TF-IDF: 0.19382
# 	Token: mess, TF-IDF: 0.18827
# 	Token: be, TF-IDF: 0.15021
#
#
# En Vogue My Lovin' (You're Never Gonna Get It) 1992
# 	Token: bop, TF-IDF: 1.05953
# 	Token: it, TF-IDF: 0.38217
# 	Token: change, TF-IDF: 0.17789
# 	Token: losing, TF-IDF: 0.1434
# 	Token: greedy, TF-IDF: 0.13244
#
#
# Jodeci Come & Talk To Me 1992
# 	Token: game, TF-IDF: 0.25905
# 	Token: name, TF-IDF: 0.2193
# 	Token: you, TF-IDF: 0.15665
# 	Token: day, TF-IDF: 0.08433
# 	Token: on, TF-IDF: 0.07086
#
#
# R. Kelly & Public Announcement Honey Love 1992
# 	Token: lights, TF-IDF: 0.23814
# 	Token: hey, TF-IDF: 0.19358
# 	Token: baby, TF-IDF: 0.14718
# 	Token: listen, TF-IDF: 0.12958
# 	Token: ohyeah, TF-IDF: 0.10011
#
#
# Michael Jackson In The Closet 1992
# 	Token: it, TF-IDF: 0.34196
# 	Token: closet, TF-IDF: 0.14413
# 	Token: other, TF-IDF: 0.11528
# 	Token: just, TF-IDF: 0.11182
# 	Token: baby, TF-IDF: 0.09559
#
#
# Lionel Richie Do It To Me 1992
# 	Token: baby, TF-IDF: 0.20445
# 	Token: love, TF-IDF: 0.14867
# 	Token: mine, TF-IDF: 0.11688
# 	Token: chance, TF-IDF: 0.10028
# 	Token: fire, TF-IDF: 0.09688
#
#
# Arrested Development Tennessee 1992
# 	Token: land, TF-IDF: 0.22319
# 	Token: plan, TF-IDF: 0.21392
# 	Token: horseshoes, TF-IDF: 0.17986
# 	Token: place, TF-IDF: 0.1456
# 	Token: from, TF-IDF: 0.11156
#
#
# Luther Vandross And Janet Jackson With BBD And Ralph Tresvant The Best Things In Life Are Free 1992
#
#
# Mary J. Blige You Remind Me (From "Strictly Business") 1992
# 	Token: him, TF-IDF: 0.03266
# 	Token: bloom, TF-IDF: 0.02709
# 	Token: king, TF-IDF: 0.02669
# 	Token: here, TF-IDF: 0.02401
# 	Token: poulaphouca, TF-IDF: 0.02258
#
#
# En Vogue Giving Him Something He Can Feel 1992
# 	Token: feel, TF-IDF: 0.61038
# 	Token: real, TF-IDF: 0.35872
# 	Token: uptight, TF-IDF: 0.17115
# 	Token: seems, TF-IDF: 0.14879
# 	Token: man, TF-IDF: 0.13211
#
#
# TLC Baby-Baby-Baby 1992
# 	Token: factual, TF-IDF: 0.27925
# 	Token: to, TF-IDF: 0.27725
# 	Token: sex, TF-IDF: 0.22143
# 	Token: less, TF-IDF: 0.20629
# 	Token: off, TF-IDF: 0.14632
#
#
# Boyz II Men End Of The Road (From "Boomerang") 1992
# 	Token: mst, TF-IDF: 5.30579
#
#
# Bobby Brown Humpin' Around 1992
# 	Token: someone, TF-IDF: 0.32737
# 	Token: around, TF-IDF: 0.21709
# 	Token: way, TF-IDF: 0.13497
# 	Token: clout, TF-IDF: 0.09647
# 	Token: grovin, TF-IDF: 0.09647
#
#
# R. Kelly & Public Announcement Slow Dance (Hey Mr. DJ) 1992
# 	Token: with, TF-IDF: 0.52063
# 	Token: slow, TF-IDF: 0.17906
# 	Token: dj, TF-IDF: 0.14849
# 	Token: desires, TF-IDF: 0.14849
# 	Token: grind, TF-IDF: 0.13302
#
#
# Tevin Campbell Alone With You 1992
# 	Token: aggression, TF-IDF: 0.36752
# 	Token: ooohhh, TF-IDF: 0.19897
# 	Token: lesson, TF-IDF: 0.16461
# 	Token: again, TF-IDF: 0.13043
# 	Token: end, TF-IDF: 0.12341
#
#
# Mary J. Blige Real Love 1992
# 	Token: love, TF-IDF: 0.57252
# 	Token: free, TF-IDF: 0.39172
# 	Token: inspiration, TF-IDF: 0.11534
# 	Token: storm, TF-IDF: 0.10653
# 	Token: need, TF-IDF: 0.10624
#
#
# Al B. Sure! Right Now 1992
# 	Token: affection, TF-IDF: 0.30303
# 	Token: jams, TF-IDF: 0.19835
# 	Token: honey, TF-IDF: 0.18939
# 	Token: tv, TF-IDF: 0.18319
# 	Token: nowhere, TF-IDF: 0.18319
#
#
# Troop Sweet November 1992
# 	Token: october, TF-IDF: 0.31211
# 	Token: feelings, TF-IDF: 0.25821
# 	Token: together, TF-IDF: 0.20835
# 	Token: was, TF-IDF: 0.19764
# 	Token: lady, TF-IDF: 0.15687
#
#
# Miki Howard Ain't Nobody Like You 1992
# 	Token: nobody, TF-IDF: 0.68496
# 	Token: babe, TF-IDF: 0.24594
# 	Token: ground, TF-IDF: 0.12785
# 	Token: up, TF-IDF: 0.09066
# 	Token: poor, TF-IDF: 0.08957
#
#
# Chuckii Booker Games 1992
# 	Token: play, TF-IDF: 0.71541
# 	Token: whoo, TF-IDF: 0.20418
# 	Token: to, TF-IDF: 0.17559
# 	Token: game, TF-IDF: 0.12952
# 	Token: paying, TF-IDF: 0.11054
#
#
# Shai If I Ever Fall In Love 1992
# 	Token: friend, TF-IDF: 0.61359
# 	Token: shai, TF-IDF: 0.12633
# 	Token: attraction, TF-IDF: 0.12633
# 	Token: thin, TF-IDF: 0.12633
# 	Token: remix, TF-IDF: 0.11667
#
#
# Whitney Houston I Will Always Love You 1992
# 	Token: you, TF-IDF: 0.242
# 	Token: kind, TF-IDF: 0.14632
# 	Token: always, TF-IDF: 0.14632
# 	Token: goodbye, TF-IDF: 0.13065
# 	Token: happiness, TF-IDF: 0.13065
#
#
# Whitney Houston I Will Always Love You 1993
# 	Token: you, TF-IDF: 0.242
# 	Token: kind, TF-IDF: 0.14632
# 	Token: always, TF-IDF: 0.14632
# 	Token: goodbye, TF-IDF: 0.13065
# 	Token: happiness, TF-IDF: 0.13065
#
#
# Naughty By Nature Hip Hop Hooray 1993
# 	Token: hooray, TF-IDF: 0.47808
# 	Token: ho, TF-IDF: 0.28093
# 	Token: heyho, TF-IDF: 0.19411
# 	Token: heyhoheyho, TF-IDF: 0.19411
# 	Token: hill, TF-IDF: 0.12941
#
#
# Dr. Dre Nuthin' But A "G" Thang 1993
# 	Token: a, TF-IDF: 0.28961
# 	Token: feeling, TF-IDF: 0.13016
# 	Token: episode, TF-IDF: 0.11808
# 	Token: those, TF-IDF: 0.11115
# 	Token: side, TF-IDF: 0.09907
#
#
# Silk Freak Me 1993
# 	Token: hot, TF-IDF: 0.44356
# 	Token: drip, TF-IDF: 0.21223
# 	Token: boast, TF-IDF: 0.21223
# 	Token: scream, TF-IDF: 0.19601
# 	Token: freaky, TF-IDF: 0.19601
#
#
# Janet Jackson That's The Way Love Goes 1993
# 	Token: goes, TF-IDF: 1.10768
# 	Token: desire, TF-IDF: 0.44055
# 	Token: fire, TF-IDF: 0.26115
# 	Token: and, TF-IDF: 0.1245
# 	Token: candles, TF-IDF: 0.11534
#
#
# H-Town Knockin' Da Boots 1993
# 	Token: love, TF-IDF: 0.20259
# 	Token: ready, TF-IDF: 0.15507
# 	Token: dawn, TF-IDF: 0.12471
# 	Token: baby, TF-IDF: 0.10501
# 	Token: right, TF-IDF: 0.08493
#
#
# SWV Weak 1993
# 	Token: sweet, TF-IDF: 0.34348
# 	Token: feet, TF-IDF: 0.34168
# 	Token: weak, TF-IDF: 0.33216
# 	Token: amazing, TF-IDF: 0.29759
# 	Token: pride, TF-IDF: 0.27478
#
#
# Tag Team Whoomp! (There It Is) 1993
# 	Token: is, TF-IDF: 0.59682
# 	Token: shaka, TF-IDF: 0.23581
# 	Token: roll'n, TF-IDF: 0.11791
# 	Token: school, TF-IDF: 0.08448
# 	Token: it, TF-IDF: 0.08379
#
#
# Jodeci Lately 1993
# 	Token: wishes, TF-IDF: 0.37017
# 	Token: misses, TF-IDF: 0.37017
# 	Token: hide, TF-IDF: 0.28277
# 	Token: goodbye, TF-IDF: 0.27345
# 	Token: cry, TF-IDF: 0.21688
#
#
# Ice Cube Featuring Das EFX Check Yo Self 1993
# 	Token: self, TF-IDF: 0.92709
# 	Token: check, TF-IDF: 0.34112
# 	Token: health, TF-IDF: 0.24933
# 	Token: born, TF-IDF: 0.12467
# 	Token: neck, TF-IDF: 0.11371
#
#
# SWV Right Here (Human Nature)/Downtown 1993
#
#
# Xscape Just Kickin' It 1993
# 	Token: beat, TF-IDF: 0.55298
# 	Token: niggas, TF-IDF: 0.51113
# 	Token: feet, TF-IDF: 0.48871
# 	Token: woman, TF-IDF: 0.33603
# 	Token: it, TF-IDF: 0.27424
#
#
# DRS Gangsta Lean 1993
# 	Token: homies, TF-IDF: 0.4884
# 	Token: lean, TF-IDF: 0.38146
# 	Token: there, TF-IDF: 0.20633
# 	Token: soon, TF-IDF: 0.15492
# 	Token: memory, TF-IDF: 0.15492
#
#
# Tevin Campbell Can We Talk 1993
# 	Token: minute, TF-IDF: 0.61712
# 	Token: name, TF-IDF: 0.48336
# 	Token: talk, TF-IDF: 0.23997
# 	Token: baby, TF-IDF: 0.0995
# 	Token: standing, TF-IDF: 0.09414
#
#
# Tevin Campbell Can We Talk 1994
# 	Token: minute, TF-IDF: 0.61712
# 	Token: name, TF-IDF: 0.48336
# 	Token: talk, TF-IDF: 0.23997
# 	Token: baby, TF-IDF: 0.0995
# 	Token: standing, TF-IDF: 0.09414
#
#
# Jodeci Cry For You 1994
# 	Token: baby, TF-IDF: 0.16811
# 	Token: tonight, TF-IDF: 0.15931
# 	Token: worthless, TF-IDF: 0.09148
# 	Token: edge, TF-IDF: 0.08449
# 	Token: anybody, TF-IDF: 0.08449
#
#
# Xscape Understanding 1994
# 	Token: understanding, TF-IDF: 0.54448
# 	Token: understand, TF-IDF: 0.22626
# 	Token: communicate, TF-IDF: 0.19651
# 	Token: dies, TF-IDF: 0.19651
# 	Token: unsure, TF-IDF: 0.19651
#
#
# R. Kelly Bump N' Grind 1994
# 	Token: grind, TF-IDF: 1.35061
# 	Token: huh, TF-IDF: 0.15401
# 	Token: constantly, TF-IDF: 0.12565
# 	Token: doors, TF-IDF: 0.11827
# 	Token: woah, TF-IDF: 0.11827
#
#
# Aaliyah Back & Forth 1994
# 	Token: forth, TF-IDF: 1.252
# 	Token: liyah, TF-IDF: 0.37898
# 	Token: go, TF-IDF: 0.27087
# 	Token: moving, TF-IDF: 0.26358
# 	Token: alright, TF-IDF: 0.22204
#
#
# Janet Jackson Any Time, Any Place/And On And On 1994
# 	Token: skillz, TF-IDF: 0.32484
# 	Token: underground, TF-IDF: 0.10828
# 	Token: baselines, TF-IDF: 0.10828
# 	Token: friendly, TF-IDF: 0.10828
# 	Token: metropolis, TF-IDF: 0.10828
#
#
# Boyz II Men I'll Make Love To You 1994
# 	Token: to, TF-IDF: 0.45152
# 	Token: night, TF-IDF: 0.3943
# 	Token: ask, TF-IDF: 0.23335
# 	Token: tight, TF-IDF: 0.15075
# 	Token: go, TF-IDF: 0.15049
#
#
# Brandy I Wanna Be Down 1994
# 	Token: down, TF-IDF: 0.47767
# 	Token: true, TF-IDF: 0.3289
# 	Token: through, TF-IDF: 0.24154
# 	Token: of, TF-IDF: 0.12434
# 	Token: for, TF-IDF: 0.10133
#
#
# Barry White Practice What You Preach 1994
# 	Token: preach, TF-IDF: 0.56445
# 	Token: teach, TF-IDF: 0.45156
# 	Token: keep, TF-IDF: 0.26854
# 	Token: would, TF-IDF: 0.20852
# 	Token: that, TF-IDF: 0.1527
#
#
# TLC Creep 1994
# 	Token: low, TF-IDF: 0.41292
# 	Token: do, TF-IDF: 0.20613
# 	Token: creep, TF-IDF: 0.20055
# 	Token: yeah, TF-IDF: 0.16843
# 	Token: know, TF-IDF: 0.13036
#
#
# TLC Creep 1995
# 	Token: low, TF-IDF: 0.41292
# 	Token: do, TF-IDF: 0.20613
# 	Token: creep, TF-IDF: 0.20055
# 	Token: yeah, TF-IDF: 0.16843
# 	Token: know, TF-IDF: 0.13036
#
#
# Brandy Baby 1995
# 	Token: yeah, TF-IDF: 0.3278
# 	Token: baby, TF-IDF: 0.31502
# 	Token: fine, TF-IDF: 0.24352
# 	Token: time, TF-IDF: 0.10494
# 	Token: situation, TF-IDF: 0.08163
#
#
# Soul For Real Candy Rain 1995
# 	Token: raindrops, TF-IDF: 1.32645
# 	Token: rain, TF-IDF: 0.65325
# 	Token: of, TF-IDF: 0.60444
# 	Token: are, TF-IDF: 0.1727
# 	Token: someone, TF-IDF: 0.10003
#
#
# Montell Jordan This Is How We Do It 1995
# 	Token: does, TF-IDF: 0.45941
# 	Token: because, TF-IDF: 0.29701
# 	Token: g, TF-IDF: 0.21963
# 	Token: flavor, TF-IDF: 0.20576
# 	Token: truck, TF-IDF: 0.13717
#
#
# Method Man Featuring Mary J. Blige I'll Be There For You/You're All I Need To Get By 1995
# 	Token: ahhhhh, TF-IDF: 0.21656
# 	Token: luxury, TF-IDF: 0.10828
# 	Token: x's, TF-IDF: 0.10828
# 	Token: blige, TF-IDF: 0.10828
# 	Token: dew, TF-IDF: 0.10828
#
#
# Monica Don't Take It Personal (Just One Of Dem Days) 1995
# 	Token: personal, TF-IDF: 1.14959
# 	Token: days, TF-IDF: 0.50689
# 	Token: through, TF-IDF: 0.24154
# 	Token: wrong, TF-IDF: 0.21648
# 	Token: alone, TF-IDF: 0.18086
#
#
# The Notorious B.I.G. One More Chance/Stay With Me 1995
# 	Token: chance, TF-IDF: 0.19429
# 	Token: stroke, TF-IDF: 0.16581
# 	Token: yourself, TF-IDF: 0.10082
# 	Token: am, TF-IDF: 0.09545
# 	Token: else, TF-IDF: 0.09385
#
#
# Shaggy Boombastic/In The Summertime 1995
# 	Token: feat, TF-IDF: 0.11627
# 	Token: williams, TF-IDF: 0.07956
# 	Token: rihanna, TF-IDF: 0.0612
# 	Token: queen, TF-IDF: 0.05063
# 	Token: brot, TF-IDF: 0.04896
#
#
# Michael Jackson You Are Not Alone 1995
# 	Token: alone, TF-IDF: 0.77298
# 	Token: away, TF-IDF: 0.14865
# 	Token: apart, TF-IDF: 0.14799
# 	Token: stay, TF-IDF: 0.13259
# 	Token: says, TF-IDF: 0.12637
#
#
# Mariah Carey Fantasy 1995
# 	Token: daydreams, TF-IDF: 0.75797
# 	Token: baby, TF-IDF: 0.25073
# 	Token: rapture, TF-IDF: 0.15159
# 	Token: boyfriend, TF-IDF: 0.14001
# 	Token: slowly, TF-IDF: 0.12541
#
#
# Xscape Who Can I Run To 1995
# 	Token: to, TF-IDF: 0.46825
# 	Token: laughter, TF-IDF: 0.29477
# 	Token: space, TF-IDF: 0.22517
# 	Token: determination, TF-IDF: 0.14738
# 	Token: love, TF-IDF: 0.14631
#
#
# R. Kelly You Remind Me Of Something 1995
# 	Token: account, TF-IDF: 0.52773
# 	Token: it, TF-IDF: 0.30456
# 	Token: baby, TF-IDF: 0.18001
# 	Token: sexy, TF-IDF: 0.14193
# 	Token: crazy, TF-IDF: 0.08097
#
#
# Whitney Houston Exhale (Shoop Shoop) (From "Waiting To Exhale") 1996
#
#
# Monica Before You Walk Out Of My Life/Like This And Like That 1996
# 	Token: mindy, TF-IDF: 0.15159
# 	Token: okay, TF-IDF: 0.08727
# 	Token: what, TF-IDF: 0.08581
# 	Token: chair, TF-IDF: 0.05648
# 	Token: phone, TF-IDF: 0.05373
#
#
# Mary J. Blige Not Gon' Cry (From "Waiting To Exhale") 1996
#
#
# R. Kelly Featuring Ronald Isley Down Low (Nobody Has To Know) 1996
# 	Token: low, TF-IDF: 0.90449
# 	Token: know, TF-IDF: 0.32124
# 	Token: car, TF-IDF: 0.15677
# 	Token: miss, TF-IDF: 0.14475
# 	Token: word, TF-IDF: 0.14475
#
#
# SWV You're The One 1996
# 	Token: one, TF-IDF: 0.47874
# 	Token: need, TF-IDF: 0.36654
# 	Token: further, TF-IDF: 0.26529
# 	Token: chance, TF-IDF: 0.15543
# 	Token: her, TF-IDF: 0.13515
#
#
# Mariah Carey Always Be My Baby 1996
# 	Token: indefinitely, TF-IDF: 0.40814
# 	Token: strong, TF-IDF: 0.18264
# 	Token: baby, TF-IDF: 0.16876
# 	Token: babe, TF-IDF: 0.14615
# 	Token: no, TF-IDF: 0.12397
#
#
# Bone Thugs-N-Harmony Tha Crossroads 1996
# 	Token: crossroads, TF-IDF: 0.58454
# 	Token: lonely, TF-IDF: 0.34922
# 	Token: pray, TF-IDF: 0.27478
# 	Token: everybody, TF-IDF: 0.16109
# 	Token: roll, TF-IDF: 0.14262
#
#
# Toni Braxton You're Makin' Me High/Let It Flow 1996
# 	Token: moments, TF-IDF: 0.20807
# 	Token: catalogue, TF-IDF: 0.20807
# 	Token: female, TF-IDF: 0.19217
# 	Token: aside, TF-IDF: 0.10404
# 	Token: classics, TF-IDF: 0.10404
#
#
# R. Kelly I Can't Sleep Baby (If I) 1996
# 	Token: babe, TF-IDF: 0.66083
# 	Token: baby, TF-IDF: 0.21197
# 	Token: around, TF-IDF: 0.15574
# 	Token: end, TF-IDF: 0.14308
# 	Token: mean, TF-IDF: 0.14028
#
#
# Keith Sweat Twisted 1996
# 	Token: baby, TF-IDF: 0.27859
# 	Token: tonight, TF-IDF: 0.14143
# 	Token: strong, TF-IDF: 0.12921
# 	Token: headaches, TF-IDF: 0.10828
# 	Token: concentrate, TF-IDF: 0.10828
#
#
# New Edition Hit Me Off 1996
# 	Token: off, TF-IDF: 0.64988
# 	Token: crazy, TF-IDF: 0.20506
# 	Token: money, TF-IDF: 0.14654
# 	Token: baby, TF-IDF: 0.13929
# 	Token: screwing, TF-IDF: 0.06891
#
#
# Aaliyah If Your Girl Only Knew 1996
# 	Token: knew, TF-IDF: 0.48076
# 	Token: huh, TF-IDF: 0.48051
# 	Token: worry, TF-IDF: 0.46126
# 	Token: phone, TF-IDF: 0.32909
# 	Token: gone, TF-IDF: 0.25024
#
#
# Az Yet Last Night (From "The Nutty Professor") 1996
#
#
# BLACKstreet (Featuring Dr. Dre) No Diggity 1996
# 	Token: it, TF-IDF: 0.14664
# 	Token: up, TF-IDF: 0.13834
# 	Token: diggity, TF-IDF: 0.11791
# 	Token: playette, TF-IDF: 0.11791
# 	Token: blackstreet, TF-IDF: 0.11791
#
#
# Ginuwine Pony 1996
# 	Token: pony, TF-IDF: 1.1938
# 	Token: it, TF-IDF: 0.23567
# 	Token: off, TF-IDF: 0.2085
# 	Token: limits, TF-IDF: 0.13264
# 	Token: flossing, TF-IDF: 0.13264
#
#
# Keith Sweat Featuring Athena Cage Nobody 1996
# 	Token: nobody, TF-IDF: 0.51124
# 	Token: on, TF-IDF: 0.45289
# 	Token: bite, TF-IDF: 0.21306
# 	Token: drop, TF-IDF: 0.18292
# 	Token: baby, TF-IDF: 0.16957
#
#
# R. Kelly I Believe I Can Fly (From "Space Jam") 1996
# 	Token: shit, TF-IDF: 0.07097
# 	Token: bitch, TF-IDF: 0.06456
# 	Token: uh, TF-IDF: 0.05223
# 	Token: niggas, TF-IDF: 0.04322
# 	Token: yuh, TF-IDF: 0.03711
#
#
# R. Kelly I Believe I Can Fly (From "Space Jam") 1997
# 	Token: shit, TF-IDF: 0.07097
# 	Token: bitch, TF-IDF: 0.06456
# 	Token: uh, TF-IDF: 0.05223
# 	Token: niggas, TF-IDF: 0.04322
# 	Token: yuh, TF-IDF: 0.03711
#
#
# En Vogue Don't Let Go (Love) 1997
# 	Token: pretend, TF-IDF: 0.629
# 	Token: shaking, TF-IDF: 0.48234
# 	Token: friends, TF-IDF: 0.40953
# 	Token: go, TF-IDF: 0.17956
# 	Token: control, TF-IDF: 0.17281
#
#
# Erykah Badu On & On 1997
# 	Token: stone, TF-IDF: 0.52219
# 	Token: on, TF-IDF: 0.365
# 	Token: names, TF-IDF: 0.26109
# 	Token: turning, TF-IDF: 0.20022
# 	Token: same, TF-IDF: 0.17596
#
#
# Dru Hill In My Bed 1997
# 	Token: babe, TF-IDF: 0.17272
# 	Token: why, TF-IDF: 0.1439
# 	Token: bed, TF-IDF: 0.1413
# 	Token: head, TF-IDF: 0.1413
# 	Token: place, TF-IDF: 0.13016
#
#
# Puff Daddy (Featuring Mase) Can't Nobody Hold Me Down 1997
# 	Token: under, TF-IDF: 0.20022
# 	Token: edge, TF-IDF: 0.18492
# 	Token: uhuh, TF-IDF: 0.18492
# 	Token: moving, TF-IDF: 0.17406
# 	Token: pride, TF-IDF: 0.15294
#
#
# The Notorious B.I.G. Hypnotize 1997
# 	Token: paid, TF-IDF: 0.59163
# 	Token: ways, TF-IDF: 0.29143
# 	Token: see, TF-IDF: 0.20763
# 	Token: instinct, TF-IDF: 0.0829
# 	Token: stink, TF-IDF: 0.0829
#
#
# Changing Faces G.H.E.T.T.O.U.T. 1997
# 	Token: else, TF-IDF: 0.50902
# 	Token: myself, TF-IDF: 0.37559
# 	Token: phone, TF-IDF: 0.33467
# 	Token: seeking, TF-IDF: 0.26979
# 	Token: alone, TF-IDF: 0.25749
#
#
# Puff Daddy & Faith Evans Featuring 112 I'll Be Missing You 1997
# 	Token: take, TF-IDF: 0.23655
# 	Token: pray, TF-IDF: 0.20785
# 	Token: break, TF-IDF: 0.18467
# 	Token: big, TF-IDF: 0.17741
# 	Token: again, TF-IDF: 0.13378
#
#
# Dru Hill Never Make A Promise 1997
# 	Token: wanted, TF-IDF: 0.32181
# 	Token: promise, TF-IDF: 0.29352
# 	Token: keep, TF-IDF: 0.29352
# 	Token: need, TF-IDF: 0.17048
# 	Token: me, TF-IDF: 0.06742
#
#
# Usher You Make Me Wanna... 1997
# 	Token: with, TF-IDF: 0.7954
# 	Token: wanna, TF-IDF: 0.41071
# 	Token: do, TF-IDF: 0.26338
# 	Token: me, TF-IDF: 0.06814
# 	Token: byebye, TF-IDF: 0.06806
#
#
# LSG My Body 1997
# 	Token: body, TF-IDF: 0.90274
# 	Token: babe, TF-IDF: 0.52775
# 	Token: down, TF-IDF: 0.08846
# 	Token: girl, TF-IDF: 0.08453
# 	Token: baby, TF-IDF: 0.08125
#
#
# Boyz II Men A Song For Mama 1997
# 	Token: stars, TF-IDF: 0.27434
# 	Token: soul, TF-IDF: 0.20568
# 	Token: be, TF-IDF: 0.15334
# 	Token: anything, TF-IDF: 0.14642
# 	Token: heart, TF-IDF: 0.13986
#
#
# Boyz II Men A Song For Mama 1998
# 	Token: stars, TF-IDF: 0.27434
# 	Token: soul, TF-IDF: 0.20568
# 	Token: be, TF-IDF: 0.15334
# 	Token: anything, TF-IDF: 0.14642
# 	Token: heart, TF-IDF: 0.13986
#
#
# LSG My Body 1998
# 	Token: body, TF-IDF: 0.90274
# 	Token: babe, TF-IDF: 0.52775
# 	Token: down, TF-IDF: 0.08846
# 	Token: girl, TF-IDF: 0.08453
# 	Token: baby, TF-IDF: 0.08125
#
#
# Usher Nice & Slow 1998
# 	Token: will, TF-IDF: 0.23912
# 	Token: slow, TF-IDF: 0.22726
# 	Token: quiet, TF-IDF: 0.16181
# 	Token: rush, TF-IDF: 0.16181
# 	Token: minutes, TF-IDF: 0.10203
#
#
# Destiny's Child No, No, No 1998
# 	Token: remix, TF-IDF: 0.52131
# 	Token: no, TF-IDF: 0.36575
# 	Token: yeah, TF-IDF: 0.16485
# 	Token: signs, TF-IDF: 0.05644
# 	Token: size, TF-IDF: 0.05644
#
#
# Montell Jordan Feat. Master P & Silkk The Shocker Let's Ride 1998
# 	Token: limit, TF-IDF: 0.15314
# 	Token: ride, TF-IDF: 0.11754
# 	Token: roudy, TF-IDF: 0.11054
# 	Token: it, TF-IDF: 0.08838
# 	Token: roll, TF-IDF: 0.08765
#
#
# K-Ci & JoJo All My Life 1998
# 	Token: too, TF-IDF: 0.35566
# 	Token: glows, TF-IDF: 0.22578
# 	Token: you, TF-IDF: 0.16413
# 	Token: stranger, TF-IDF: 0.10426
# 	Token: glow, TF-IDF: 0.10426
#
#
# Next Too Close 1998
# 	Token: excited, TF-IDF: 0.51045
# 	Token: slow, TF-IDF: 0.3693
# 	Token: it, TF-IDF: 0.23567
# 	Token: move, TF-IDF: 0.14642
# 	Token: requested, TF-IDF: 0.11054
#
#
# Janet Featuring BLACKstreet I Get Lonely 1998
# 	Token: dear, TF-IDF: 0.59247
# 	Token: lonely, TF-IDF: 0.53517
# 	Token: you, TF-IDF: 0.08839
# 	Token: down, TF-IDF: 0.08271
# 	Token: me, TF-IDF: 0.07529
#
#
# Brandy & Monica The Boy Is Mine 1998
# 	Token: mine, TF-IDF: 0.41407
# 	Token: see, TF-IDF: 0.12656
# 	Token: confused, TF-IDF: 0.10561
# 	Token: up, TF-IDF: 0.08893
# 	Token: mistake, TF-IDF: 0.0758
#
#
# Kelly Price Friend Of Mine 1998
# 	Token: cheater, TF-IDF: 0.30319
# 	Token: friend, TF-IDF: 0.24544
# 	Token: knew, TF-IDF: 0.19623
# 	Token: betrayed, TF-IDF: 0.15159
# 	Token: cheated, TF-IDF: 0.15159
#
#
# Monica The First Night 1998
# 	Token: won, TF-IDF: 0.47597
# 	Token: wrong, TF-IDF: 0.31298
# 	Token: not, TF-IDF: 0.31049
# 	Token: right, TF-IDF: 0.19952
# 	Token: night, TF-IDF: 0.19952
#
#
# Dru Hill Featuring Redman How Deep Is Your Love 1998
# 	Token: yourself, TF-IDF: 0.20815
# 	Token: me, TF-IDF: 0.17264
# 	Token: papi, TF-IDF: 0.17115
# 	Token: chico, TF-IDF: 0.17115
# 	Token: mami, TF-IDF: 0.17115
#
#
# Deborah Cox Nobody's Supposed To Be Here 1998
# 	Token: here, TF-IDF: 0.34268
# 	Token: butterfly, TF-IDF: 0.24277
# 	Token: eternity, TF-IDF: 0.23103
# 	Token: wings, TF-IDF: 0.23103
# 	Token: learn, TF-IDF: 0.22143
#
#
# Deborah Cox Nobody's Supposed To Be Here 1999
# 	Token: here, TF-IDF: 0.34268
# 	Token: butterfly, TF-IDF: 0.24277
# 	Token: eternity, TF-IDF: 0.23103
# 	Token: wings, TF-IDF: 0.23103
# 	Token: learn, TF-IDF: 0.22143
#
#
# Whitney Houston Feat. Faith Evans & Kelly Price Heartbreak Hotel 1999
# 	Token: hotel, TF-IDF: 0.77175
# 	Token: cry, TF-IDF: 0.2826
# 	Token: letter, TF-IDF: 0.16773
# 	Token: mind, TF-IDF: 0.13731
# 	Token: right, TF-IDF: 0.13382
#
#
# Busta Rhymes Featuring Janet What's It Gonna Be?! 1999
# 	Token: wet, TF-IDF: 0.42415
# 	Token: common, TF-IDF: 0.24179
# 	Token: be, TF-IDF: 0.23265
# 	Token: yes, TF-IDF: 0.22251
# 	Token: gonna, TF-IDF: 0.15136
#
#
# TLC No Scrubs 1999
# 	Token: scrubs, TF-IDF: 0.66322
# 	Token: ride, TF-IDF: 0.39179
# 	Token: me, TF-IDF: 0.11769
# 	Token: and, TF-IDF: 0.07954
# 	Token: rising, TF-IDF: 0.07369
#
#
# Maxwell Fortunate 1999
# 	Token: this, TF-IDF: 0.54807
# 	Token: recite, TF-IDF: 0.22107
# 	Token: ignite, TF-IDF: 0.22107
# 	Token: interlude, TF-IDF: 0.22107
# 	Token: flight, TF-IDF: 0.19219
#
#
# Destiny's Child Bills, Bills, Bills 1999
# 	Token: bills, TF-IDF: 1.30675
# 	Token: chill, TF-IDF: 0.37397
# 	Token: brother, TF-IDF: 0.28048
# 	Token: another, TF-IDF: 0.2702
# 	Token: through, TF-IDF: 0.2147
#
#
# Faith Evans Never Gonna Let You Go 1999
# 	Token: so, TF-IDF: 0.32467
# 	Token: go, TF-IDF: 0.25623
# 	Token: boy, TF-IDF: 0.20797
# 	Token: true, TF-IDF: 0.14815
# 	Token: blessed, TF-IDF: 0.13244
#
#
# Eric Benet Featuring Tamia Spend My Life With You 1999
# 	Token: understands, TF-IDF: 0.18949
# 	Token: eyes, TF-IDF: 0.18797
# 	Token: when, TF-IDF: 0.16474
# 	Token: hand, TF-IDF: 0.10909
# 	Token: world, TF-IDF: 0.09047
#
#
# Mariah Carey Featuring Jay-Z Heartbreaker 1999
# 	Token: incessantly, TF-IDF: 0.36592
# 	Token: start, TF-IDF: 0.27952
# 	Token: love, TF-IDF: 0.22704
# 	Token: heart, TF-IDF: 0.20577
# 	Token: used, TF-IDF: 0.11265
#
#
# Puff Daddy Featuring R. Kelly Satisfy You 1999
# 	Token: do, TF-IDF: 0.19823
# 	Token: witchu, TF-IDF: 0.12941
# 	Token: you, TF-IDF: 0.07194
# 	Token: appearance, TF-IDF: 0.0647
# 	Token: spirits, TF-IDF: 0.0647
#
#
# Donell Jones U Know What's Up 1999
# 	Token: what, TF-IDF: 0.44492
# 	Token: up, TF-IDF: 0.40348
# 	Token: need, TF-IDF: 0.13575
# 	Token: baby, TF-IDF: 0.10834
# 	Token: parlay, TF-IDF: 0.09826
#
#
# Missy "Misdemeanor" Elliott Featuring NAS, EVE & Q-Tip Hot Boyz 2000
# 	Token: boy, TF-IDF: 0.24428
# 	Token: want, TF-IDF: 0.13847
# 	Token: boyz, TF-IDF: 0.12633
# 	Token: jeeps, TF-IDF: 0.12633
# 	Token: visa's, TF-IDF: 0.12633
#
#
# Montell Jordan Get It On Tonite 2000
# 	Token: tonight, TF-IDF: 0.66636
# 	Token: alright, TF-IDF: 0.2989
# 	Token: floor, TF-IDF: 0.12657
# 	Token: scheming, TF-IDF: 0.10203
# 	Token: tricking, TF-IDF: 0.10203
#
#
# Mariah Carey Featuring Joe & 98 Degrees Thank God I Found You 2000
# 	Token: gratitude, TF-IDF: 0.4574
# 	Token: sunlight, TF-IDF: 0.27444
# 	Token: reality, TF-IDF: 0.23858
# 	Token: dream, TF-IDF: 0.18176
# 	Token: life, TF-IDF: 0.15597
#
#
# Destiny's Child Say My Name 2000
# 	Token: name, TF-IDF: 0.57498
# 	Token: shady, TF-IDF: 0.38762
# 	Token: game, TF-IDF: 0.26122
# 	Token: change, TF-IDF: 0.13827
# 	Token: seems, TF-IDF: 0.11629
#
#
# Santana Featuring The Product G&B Maria Maria 2000
# 	Token: chola, TF-IDF: 0.50531
# 	Token: maria, TF-IDF: 0.42109
# 	Token: santana, TF-IDF: 0.38891
# 	Token: harlem, TF-IDF: 0.25266
# 	Token: la, TF-IDF: 0.23335
#
#
# Toni Braxton He Wasn't Man Enough 2000
# 	Token: him, TF-IDF: 0.47154
# 	Token: thinking, TF-IDF: 0.30977
# 	Token: girlfriend, TF-IDF: 0.28319
# 	Token: then, TF-IDF: 0.20424
# 	Token: leave, TF-IDF: 0.20055
#
#
# Carl Thomas I Wish 2000
# 	Token: children, TF-IDF: 0.30051
# 	Token: all, TF-IDF: 0.28451
# 	Token: spent, TF-IDF: 0.18949
# 	Token: desired, TF-IDF: 0.18949
# 	Token: went, TF-IDF: 0.18949
#
#
# Avant Separated 2000
# 	Token: mmm, TF-IDF: 0.59136
# 	Token: yeah, TF-IDF: 0.2235
# 	Token: wrong, TF-IDF: 0.19983
# 	Token: sleeve, TF-IDF: 0.13605
# 	Token: separated, TF-IDF: 0.13605
#
#
# Jagged Edge Let's Get Married 2000
# 	Token: married, TF-IDF: 0.72597
# 	Token: dress, TF-IDF: 0.62329
# 	Token: confess, TF-IDF: 0.62329
# 	Token: it, TF-IDF: 0.13966
# 	Token: relevant, TF-IDF: 0.09826
#
#
# Sisqo Incomplete 2000
# 	Token: incomplete, TF-IDF: 0.54448
# 	Token: everything, TF-IDF: 0.42206
# 	Token: cars, TF-IDF: 0.24886
# 	Token: fool, TF-IDF: 0.21803
# 	Token: see, TF-IDF: 0.14062
#
#
# Ruff Endz No More 2000
# 	Token: more, TF-IDF: 0.21071
# 	Token: out, TF-IDF: 0.18401
# 	Token: sprees, TF-IDF: 0.13264
# 	Token: creeps, TF-IDF: 0.13264
# 	Token: laughed, TF-IDF: 0.13264
#
#
# Next Wifey 2000
# 	Token: wifey, TF-IDF: 0.8731
# 	Token: highly, TF-IDF: 0.26865
# 	Token: complete, TF-IDF: 0.24812
# 	Token: street, TF-IDF: 0.21302
# 	Token: one, TF-IDF: 0.10773
#
#
# Lil Bow Wow Featuring Xscape Bounce With Me 2000
# 	Token: yo, TF-IDF: 0.20273
# 	Token: stomp, TF-IDF: 0.18847
# 	Token: ya, TF-IDF: 0.14437
# 	Token: floor, TF-IDF: 0.12657
# 	Token: mean, TF-IDF: 0.12409
#
#
# Profyle Liar 2000
# 	Token: breaker, TF-IDF: 0.58953
# 	Token: takin, TF-IDF: 0.58953
# 	Token: but, TF-IDF: 0.57233
# 	Token: dog, TF-IDF: 0.45034
# 	Token: all, TF-IDF: 0.22129
#
#
# Erykah Badu Bag Lady 2000
# 	Token: lady, TF-IDF: 0.55815
# 	Token: space, TF-IDF: 0.37703
# 	Token: ladies, TF-IDF: 0.25124
# 	Token: light, TF-IDF: 0.17682
# 	Token: way, TF-IDF: 0.17263
#
#
# R. Kelly I Wish 2000
# 	Token: wish, TF-IDF: 0.37066
# 	Token: somehow, TF-IDF: 0.22538
# 	Token: now, TF-IDF: 0.19517
# 	Token: place, TF-IDF: 0.1534
# 	Token: face, TF-IDF: 0.15112
#
#
# JAY-Z I Just Wanna Love U (Give It 2 Me) 2000
# 	Token: stuff, TF-IDF: 0.70889
# 	Token: me, TF-IDF: 0.11608
# 	Token: telling, TF-IDF: 0.06713
# 	Token: yelling, TF-IDF: 0.06713
# 	Token: relation, TF-IDF: 0.06713
#
#
# OutKast Ms. Jackson 2000
# 	Token: cry, TF-IDF: 0.36146
# 	Token: times, TF-IDF: 0.33813
# 	Token: real, TF-IDF: 0.32326
# 	Token: mamas, TF-IDF: 0.11396
# 	Token: out, TF-IDF: 0.08558
#
#
# Destiny's Child Independent Women Part I 2000
# 	Token: hour, TF-IDF: 0.11654
# 	Token: cost, TF-IDF: 0.08673
# 	Token: jubilee, TF-IDF: 0.08673
# 	Token: occasion, TF-IDF: 0.04337
# 	Token: embarrassment, TF-IDF: 0.04337
#
#
# Destiny's Child Independent Women Part I 2001
# 	Token: hour, TF-IDF: 0.11654
# 	Token: cost, TF-IDF: 0.08673
# 	Token: jubilee, TF-IDF: 0.08673
# 	Token: occasion, TF-IDF: 0.04337
# 	Token: embarrassment, TF-IDF: 0.04337
#
#
# JAY-Z I Just Wanna Love U (Give It 2 Me) 2001
# 	Token: stuff, TF-IDF: 0.70889
# 	Token: me, TF-IDF: 0.11608
# 	Token: telling, TF-IDF: 0.06713
# 	Token: yelling, TF-IDF: 0.06713
# 	Token: relation, TF-IDF: 0.06713
#
#
# Mystikal Featuring Nivea Danger (Been So Long) 2001
# 	Token: look, TF-IDF: 0.28433
# 	Token: flog, TF-IDF: 0.2513
# 	Token: chea, TF-IDF: 0.20407
# 	Token: see, TF-IDF: 0.19876
# 	Token: danger, TF-IDF: 0.18847
#
#
# OutKast Ms. Jackson 2001
# 	Token: cry, TF-IDF: 0.36146
# 	Token: times, TF-IDF: 0.33813
# 	Token: real, TF-IDF: 0.32326
# 	Token: mamas, TF-IDF: 0.11396
# 	Token: out, TF-IDF: 0.08558
#
#
# Joe Featuring Mystikal Stutter 2001
# 	Token: replying, TF-IDF: 0.89495
# 	Token: lying, TF-IDF: 0.8856
# 	Token: stutter, TF-IDF: 0.82656
# 	Token: well, TF-IDF: 0.16935
# 	Token: off, TF-IDF: 0.10048
#
#
# 112 It's Over Now 2001
# 	Token: this, TF-IDF: 0.34615
# 	Token: kiss, TF-IDF: 0.27742
# 	Token: anytime, TF-IDF: 0.25791
# 	Token: cool, TF-IDF: 0.16981
# 	Token: now, TF-IDF: 0.13275
#
#
# Jagged Edge Promise 2001
# 	Token: promise, TF-IDF: 0.41382
# 	Token: believe, TF-IDF: 0.18697
# 	Token: need, TF-IDF: 0.16024
# 	Token: leave, TF-IDF: 0.15288
# 	Token: so, TF-IDF: 0.1477
#
#
# Janet All For You 2001
# 	Token: fun, TF-IDF: 0.51068
# 	Token: party, TF-IDF: 0.15734
# 	Token: move, TF-IDF: 0.15734
# 	Token: body, TF-IDF: 0.13229
# 	Token: some, TF-IDF: 0.12559
#
#
# Case Missing You 2001
# 	Token: afternoon, TF-IDF: 0.4302
# 	Token: groom, TF-IDF: 0.4302
# 	Token: june, TF-IDF: 0.39732
# 	Token: sand, TF-IDF: 0.374
# 	Token: hand, TF-IDF: 0.24766
#
#
# Lil' Romeo My Baby 2001
# 	Token: girlfriend, TF-IDF: 0.53206
# 	Token: swing, TF-IDF: 0.33254
# 	Token: anyway, TF-IDF: 0.24564
# 	Token: chance, TF-IDF: 0.1884
# 	Token: okay, TF-IDF: 0.18512
#
#
# R. Kelly Featuring Jay-Z Fiesta 2001
# 	Token: fiesta, TF-IDF: 0.86373
# 	Token: 'burbs, TF-IDF: 0.24678
# 	Token: shit, TF-IDF: 0.2386
# 	Token: ma, TF-IDF: 0.21454
# 	Token: my, TF-IDF: 0.15972
#
#
# Usher U Remind Me 2001
# 	Token: knew, TF-IDF: 0.63073
# 	Token: through, TF-IDF: 0.34506
# 	Token: you, TF-IDF: 0.16669
# 	Token: fooled, TF-IDF: 0.10828
# 	Token: creep, TF-IDF: 0.09414
#
#
# Mariah Carey Featuring Da Brat & Ludacris Loverboy 2001
# 	Token: loverboy, TF-IDF: 0.18509
# 	Token: long, TF-IDF: 0.18124
# 	Token: me, TF-IDF: 0.08816
# 	Token: ride, TF-IDF: 0.0656
# 	Token: kissing, TF-IDF: 0.0617
#
#
# Alicia Keys Fallin' 2001
# 	Token: someone, TF-IDF: 0.51443
# 	Token: falling, TF-IDF: 0.26358
# 	Token: out, TF-IDF: 0.26286
# 	Token: fall, TF-IDF: 0.2008
# 	Token: you, TF-IDF: 0.15557
#
#
# Jagged Edge With Nelly Where The Party At 2001
#
#
# Ginuwine Differences 2001
# 	Token: competes, TF-IDF: 0.45156
# 	Token: sight, TF-IDF: 0.33357
# 	Token: love, TF-IDF: 0.1681
# 	Token: then, TF-IDF: 0.13471
# 	Token: buckwild, TF-IDF: 0.11289
#
#
# Mary J. Blige Family Affair 2001
# 	Token: dancery, TF-IDF: 0.52018
# 	Token: floating, TF-IDF: 0.52018
# 	Token: hateration, TF-IDF: 0.41614
# 	Token: upon, TF-IDF: 0.31211
# 	Token: waiting, TF-IDF: 0.30741
#
#
# Usher U Got It Bad 2001
# 	Token: bad, TF-IDF: 0.58074
# 	Token: someone, TF-IDF: 0.21606
# 	Token: house, TF-IDF: 0.19745
# 	Token: else, TF-IDF: 0.18019
# 	Token: track, TF-IDF: 0.16212
#
#
# Ja Rule Featuring Ashanti Always On Time 2002
# 	Token: rare, TF-IDF: 0.15159
# 	Token: other, TF-IDF: 0.11199
# 	Token: mine, TF-IDF: 0.10352
# 	Token: song, TF-IDF: 0.0806
# 	Token: him, TF-IDF: 0.07831
#
#
# Mr. Cheeks Lights, Camera, Action! 2002
# 	Token: somethin, TF-IDF: 0.51252
# 	Token: action, TF-IDF: 0.16257
# 	Token: shit, TF-IDF: 0.15833
# 	Token: jackson, TF-IDF: 0.1369
# 	Token: tonite, TF-IDF: 0.13101
#
#
# Tweet Oops (Oh My) 2002
# 	Token: my, TF-IDF: 0.55686
# 	Token: myself, TF-IDF: 0.25668
# 	Token: legs, TF-IDF: 0.23727
# 	Token: red, TF-IDF: 0.22741
# 	Token: feet, TF-IDF: 0.18162
#
#
# Ashanti Foolish 2002
# 	Token: more, TF-IDF: 0.24501
# 	Token: you, TF-IDF: 0.18995
# 	Token: inc, TF-IDF: 0.12339
# 	Token: ashanti, TF-IDF: 0.12339
# 	Token: accept, TF-IDF: 0.12339
#
#
# Cam'Ron Featuring Juelz Santana Oh Boy 2002
# 	Token: killa, TF-IDF: 0.60638
# 	Token: scrambling, TF-IDF: 0.30319
# 	Token: them, TF-IDF: 0.22557
# 	Token: huh, TF-IDF: 0.17161
# 	Token: standin, TF-IDF: 0.15159
#
#
# Nelly Hot In Herre 2002
# 	Token: ah, TF-IDF: 0.79449
# 	Token: clothes, TF-IDF: 0.34879
# 	Token: off, TF-IDF: 0.30055
# 	Token: ohhh, TF-IDF: 0.12467
# 	Token: out, TF-IDF: 0.09946
#
#
# Nelly Featuring Kelly Rowland Dilemma 2002
# 	Token: boo, TF-IDF: 0.4151
# 	Token: right, TF-IDF: 0.30331
# 	Token: cause, TF-IDF: 0.22269
# 	Token: you, TF-IDF: 0.11967
# 	Token: do, TF-IDF: 0.1042
#
#
# LL Cool J Luv U Better 2002
# 	Token: better, TF-IDF: 0.26659
# 	Token: no, TF-IDF: 0.20357
# 	Token: together, TF-IDF: 0.19885
# 	Token: today, TF-IDF: 0.13585
# 	Token: ways, TF-IDF: 0.13089
#
#
# Missy "Misdemeanor" Elliott Work It 2002
# 	Token: tup, TF-IDF: 0.89361
# 	Token: ya, TF-IDF: 0.50049
# 	Token: common, TF-IDF: 0.31
# 	Token: duh, TF-IDF: 0.1117
# 	Token: down, TF-IDF: 0.06704
#
#
# Erykah Badu Featuring Common Love Of My Life (An Ode To Hip Hop) 2002
# 	Token: life, TF-IDF: 0.27483
# 	Token: advice, TF-IDF: 0.12406
# 	Token: bgirl'n, TF-IDF: 0.12406
# 	Token: shoulder, TF-IDF: 0.11678
# 	Token: friend, TF-IDF: 0.10874
#
#
# Erykah Badu Featuring Common Love Of My Life (An Ode To Hip Hop) 2003
# 	Token: life, TF-IDF: 0.27483
# 	Token: advice, TF-IDF: 0.12406
# 	Token: bgirl'n, TF-IDF: 0.12406
# 	Token: shoulder, TF-IDF: 0.11678
# 	Token: friend, TF-IDF: 0.10874
#
#
# Aaliyah Miss You 2003
# 	Token: sometimes, TF-IDF: 0.40872
# 	Token: you, TF-IDF: 0.22401
# 	Token: mine, TF-IDF: 0.21402
# 	Token: do, TF-IDF: 0.13717
# 	Token: it's, TF-IDF: 0.12406
#
#
# 50 Cent In Da Club 2003
# 	Token: bubg, TF-IDF: 0.74281
# 	Token: drugs, TF-IDF: 0.55352
# 	Token: rubbed, TF-IDF: 0.42446
# 	Token: birthday, TF-IDF: 0.32424
# 	Token: love, TF-IDF: 0.18435
#
#
# JAY-Z Excuse Me Miss 2003
# 	Token: name, TF-IDF: 0.22638
# 	Token: trot, TF-IDF: 0.17115
# 	Token: it, TF-IDF: 0.14191
# 	Token: jayz, TF-IDF: 0.1416
# 	Token: damn, TF-IDF: 0.12264
#
#
# Sean Paul Get Busy 2003
# 	Token: us, TF-IDF: 0.67499
# 	Token: morng, TF-IDF: 0.51196
# 	Token: ting, TF-IDF: 0.27925
# 	Token: on, TF-IDF: 0.20885
# 	Token: flame, TF-IDF: 0.20231
#
#
# 50 Cent Featuring Nate Dogg 21 Questions 2003
# 	Token: murder, TF-IDF: 0.13769
# 	Token: cake, TF-IDF: 0.13769
# 	Token: song, TF-IDF: 0.08421
# 	Token: necessity, TF-IDF: 0.07919
# 	Token: fares, TF-IDF: 0.07919
#
#
# Monica So Gone 2003
# 	Token: unreal, TF-IDF: 0.63353
# 	Token: feel, TF-IDF: 0.3631
# 	Token: chick, TF-IDF: 0.14628
# 	Token: baby, TF-IDF: 0.14553
# 	Token: gone, TF-IDF: 0.11205
#
#
# Beyonce Featuring Jay Z Crazy In Love 2003
# 	Token: now, TF-IDF: 0.32755
# 	Token: looking, TF-IDF: 0.29952
# 	Token: no, TF-IDF: 0.22325
# 	Token: love, TF-IDF: 0.08551
# 	Token: can, TF-IDF: 0.08074
#
#
# Pharrell Featuring Jay-Z Frontin' 2003
# 	Token: ohhhohh, TF-IDF: 0.54418
# 	Token: oooohhh, TF-IDF: 0.40814
# 	Token: are, TF-IDF: 0.23912
# 	Token: off, TF-IDF: 0.21385
# 	Token: all, TF-IDF: 0.1532
#
#
# Beyonce Featuring Sean Paul Baby Boy 2003
# 	Token: dreams, TF-IDF: 0.33323
# 	Token: year, TF-IDF: 0.22143
# 	Token: girl, TF-IDF: 0.18019
# 	Token: by, TF-IDF: 0.1732
# 	Token: mind, TF-IDF: 0.14906
#
#
# Ludacris Featuring Shawnna Stand Up 2003
# 	Token: that, TF-IDF: 0.54509
# 	Token: back, TF-IDF: 0.17582
# 	Token: up, TF-IDF: 0.1182
# 	Token: chiali, TF-IDF: 0.06716
# 	Token: trucks, TF-IDF: 0.06716
#
#
# R. Kelly Step In The Name Of Love 2003
# 	Token: wanna, TF-IDF: 0.23102
# 	Token: heregirl, TF-IDF: 0.16581
# 	Token: around, TF-IDF: 0.14925
# 	Token: slide, TF-IDF: 0.14415
# 	Token: since, TF-IDF: 0.13717
#
#
# ...
# 	Token: think, TF-IDF: 0.502
# 	Token: sex, TF-IDF: 0.45077
# 	Token: crib, TF-IDF: 0.15677
# 	Token: sheets, TF-IDF: 0.15026
# 	Token: bed, TF-IDF: 0.11102
#
#
# Trey Songz Featuring Drake I Invented Sex 2010
# 	Token: think, TF-IDF: 0.502
# 	Token: sex, TF-IDF: 0.45077
# 	Token: crib, TF-IDF: 0.15677
# 	Token: sheets, TF-IDF: 0.15026
# 	Token: bed, TF-IDF: 0.11102
#
#
# Melanie Fiona It Kills Me 2010
# 	Token: believes, TF-IDF: 0.47422
# 	Token: hoo, TF-IDF: 0.42479
# 	Token: hoohoo, TF-IDF: 0.17115
# 	Token: ohhhh, TF-IDF: 0.15807
# 	Token: ehhhhh, TF-IDF: 0.15807
#
#
# Robin Thicke Sex Therapy 2010
# 	Token: therapy, TF-IDF: 0.77376
# 	Token: to, TF-IDF: 0.52678
# 	Token: fantasy, TF-IDF: 0.24497
# 	Token: roll, TF-IDF: 0.1753
# 	Token: like, TF-IDF: 0.1713
#
#
# Timbaland Featuring Drake Say Something 2010
# 	Token: ohhwhoa, TF-IDF: 0.24871
# 	Token: only, TF-IDF: 0.19721
# 	Token: pain, TF-IDF: 0.16472
# 	Token: lonely, TF-IDF: 0.16097
# 	Token: but, TF-IDF: 0.16097
#
#
# Monica Everything To Me 2010
# 	Token: ooooohhh, TF-IDF: 0.29477
# 	Token: whoa, TF-IDF: 0.19522
# 	Token: my, TF-IDF: 0.19078
# 	Token: oooohhhhhhh, TF-IDF: 0.14738
# 	Token: heey, TF-IDF: 0.14738
#
#
# Alicia Keys Un-Thinkable (I'm Ready) 2010
# 	Token: saying, TF-IDF: 0.3376
# 	Token: ignore, TF-IDF: 0.33161
# 	Token: crazy, TF-IDF: 0.24672
# 	Token: beautiful, TF-IDF: 0.24497
# 	Token: before, TF-IDF: 0.1877
#
#
# Usher There Goes My Baby 2010
# 	Token: girl, TF-IDF: 0.22088
# 	Token: baby, TF-IDF: 0.22017
# 	Token: takes, TF-IDF: 0.14879
# 	Token: hands, TF-IDF: 0.11077
# 	Token: do, TF-IDF: 0.10924
#
#
# Chris Brown Featuring Tyga & Kevin McCall Deuces 2010
# 	Token: bye, TF-IDF: 0.38835
# 	Token: her, TF-IDF: 0.33269
# 	Token: deuces, TF-IDF: 0.15078
# 	Token: work, TF-IDF: 0.14891
# 	Token: better, TF-IDF: 0.14611
#
#
# Trey Songz Can't Be Friends 2010
# 	Token: friends, TF-IDF: 0.25027
# 	Token: hell, TF-IDF: 0.21775
# 	Token: it, TF-IDF: 0.15712
# 	Token: crazy, TF-IDF: 0.1462
# 	Token: too, TF-IDF: 0.13267
#
#
# Trey Songz Can't Be Friends 2011
# 	Token: friends, TF-IDF: 0.25027
# 	Token: hell, TF-IDF: 0.21775
# 	Token: it, TF-IDF: 0.15712
# 	Token: crazy, TF-IDF: 0.1462
# 	Token: too, TF-IDF: 0.13267
#
#
# Jamie Foxx Featuring Drake Fall For Your Type 2011
# 	Token: type, TF-IDF: 1.1606
# 	Token: all, TF-IDF: 0.17169
# 	Token: sober, TF-IDF: 0.09148
# 	Token: impression, TF-IDF: 0.09148
# 	Token: listened, TF-IDF: 0.09148
#
#
# Nicki Minaj Featuring Drake Moment 4 Life 2011
# 	Token: alive, TF-IDF: 0.40726
# 	Token: life, TF-IDF: 0.16448
# 	Token: of, TF-IDF: 0.1413
# 	Token: skies, TF-IDF: 0.08039
# 	Token: empire, TF-IDF: 0.08039
#
#
# Chris Brown Featuring Lil Wayne & Busta Rhymes Look At Me Now 2011
# 	Token: muh'fucka, TF-IDF: 0.23322
# 	Token: dick, TF-IDF: 0.18493
# 	Token: paper, TF-IDF: 0.15207
# 	Token: okay, TF-IDF: 0.1007
# 	Token: five, TF-IDF: 0.09247
#
#
# Miguel Sure Thing 2011
# 	Token: that, TF-IDF: 0.2848
# 	Token: plain, TF-IDF: 0.25266
# 	Token: thing, TF-IDF: 0.23833
# 	Token: shine, TF-IDF: 0.193
# 	Token: fallin, TF-IDF: 0.16844
#
#
# Kelly Rowland Featuring Lil Wayne Motivation 2011
# 	Token: motivation, TF-IDF: 0.50531
# 	Token: background, TF-IDF: 0.37898
# 	Token: legs, TF-IDF: 0.31354
# 	Token: here, TF-IDF: 0.15502
# 	Token: go, TF-IDF: 0.15049
#
#
# DJ Khaled Featuring Drake, Rick Ross & Lil Wayne I'm On One 2011
# 	Token: one, TF-IDF: 0.22797
# 	Token: pink, TF-IDF: 0.18949
# 	Token: shit, TF-IDF: 0.18321
# 	Token: drink, TF-IDF: 0.15677
# 	Token: young, TF-IDF: 0.13998
#
#
# Big Sean Featuring Kanye West & Roscoe Dash Marvin & Chardonnay 2011
# 	Token: chardonnay, TF-IDF: 0.69206
# 	Token: inspired, TF-IDF: 0.38448
# 	Token: it's, TF-IDF: 0.14204
# 	Token: amazing, TF-IDF: 0.12723
# 	Token: way, TF-IDF: 0.10758
#
#
# Lil Wayne Featuring Drake She Will 2011
# 	Token: bitch, TF-IDF: 0.12
# 	Token: shit, TF-IDF: 0.09161
# 	Token: better, TF-IDF: 0.0848
# 	Token: paper, TF-IDF: 0.08237
# 	Token: her, TF-IDF: 0.0724
#
#
# Jay Z Kanye West Ni**as in Paris 2011
# 	Token: defient, TF-IDF: 0.29477
# 	Token: climate, TF-IDF: 0.29477
# 	Token: hyvent, TF-IDF: 0.29477
# 	Token: vent, TF-IDF: 0.29477
# 	Token: raising, TF-IDF: 0.29477
#
#
# Wale Featuring Miguel Lotus Flower Bomb 2012
# 	Token: be, TF-IDF: 0.15334
# 	Token: eternity, TF-IDF: 0.14632
# 	Token: fantasy, TF-IDF: 0.13065
# 	Token: mine, TF-IDF: 0.12077
# 	Token: right, TF-IDF: 0.092
#
#
# Drake Featuring Nicki Minaj Make Me Proud 2012
# 	Token: too, TF-IDF: 0.12405
# 	Token: is, TF-IDF: 0.12132
# 	Token: still, TF-IDF: 0.11981
# 	Token: fine, TF-IDF: 0.08223
# 	Token: go, TF-IDF: 0.08208
#
#
# Drake Featuring Lil Wayne The Motto 2012
#
#
# Beyonce Love On Top 2012
# 	Token: top, TF-IDF: 0.71264
# 	Token: stops, TF-IDF: 0.20672
# 	Token: call, TF-IDF: 0.19749
# 	Token: see, TF-IDF: 0.17258
# 	Token: all, TF-IDF: 0.15519
#
#
# Usher Climax 2012
# 	Token: climax, TF-IDF: 1.15763
# 	Token: undone, TF-IDF: 0.38588
# 	Token: separate, TF-IDF: 0.38588
# 	Token: fast, TF-IDF: 0.29477
# 	Token: away, TF-IDF: 0.15784
#
#
# 2 Chainz Featuring Drake No Lie 2012
# 	Token: huh, TF-IDF: 0.13651
# 	Token: brandy, TF-IDF: 0.08039
# 	Token: panties, TF-IDF: 0.08039
# 	Token: grammys, TF-IDF: 0.08039
# 	Token: chronic, TF-IDF: 0.08039
#
#
# Miguel Adorn 2012
# 	Token: freak, TF-IDF: 0.30627
# 	Token: baby, TF-IDF: 0.18282
# 	Token: subconscious, TF-IDF: 0.16581
# 	Token: projection, TF-IDF: 0.16581
# 	Token: supreme, TF-IDF: 0.16581
#
#
# Rihanna Diamonds 2012
# 	Token: diamond, TF-IDF: 1.62799
# 	Token: sky, TF-IDF: 0.76101
# 	Token: alive, TF-IDF: 0.24705
# 	Token: eye, TF-IDF: 0.16307
# 	Token: rays, TF-IDF: 0.14413
#
#
# Rihanna Diamonds 2013
# 	Token: diamond, TF-IDF: 1.62799
# 	Token: sky, TF-IDF: 0.76101
# 	Token: alive, TF-IDF: 0.24705
# 	Token: eye, TF-IDF: 0.16307
# 	Token: rays, TF-IDF: 0.14413
#
#
# Macklemore & Ryan Lewis Featuring Wanz Thrift Shop 2013
# 	Token: da, TF-IDF: 0.37898
# 	Token: hunting, TF-IDF: 0.2707
# 	Token: tags, TF-IDF: 0.25002
# 	Token: awesome, TF-IDF: 0.23534
# 	Token: pocket, TF-IDF: 0.22395
#
#
# Macklemore & Ryan Lewis Featuring Ray Dalton Can't Hold Us 2013
#
#
# Robin Thicke Featuring T.I. + Pharrell Blurred Lines 2013
# 	Token: hey, TF-IDF: 0.23512
# 	Token: it, TF-IDF: 0.1414
# 	Token: plastic, TF-IDF: 0.13264
# 	Token: blasted, TF-IDF: 0.13264
# 	Token: lines, TF-IDF: 0.12251
#
#
# Drake Featuring Majid Jordan Hold On, We're Going Home 2013
# 	Token: endlessly, TF-IDF: 0.51252
# 	Token: loved, TF-IDF: 0.25626
# 	Token: home, TF-IDF: 0.21375
# 	Token: it, TF-IDF: 0.15712
# 	Token: be, TF-IDF: 0.15334
#
#
# Eminem Featuring Rihanna The Monster 2013
# 	Token: the, TF-IDF: 0.11841
# 	Token: at, TF-IDF: 0.11125
# 	Token: head, TF-IDF: 0.10719
# 	Token: nothing, TF-IDF: 0.10356
# 	Token: newsweek, TF-IDF: 0.08449
#
#
# Eminem Featuring Rihanna The Monster 2014
# 	Token: the, TF-IDF: 0.11841
# 	Token: at, TF-IDF: 0.11125
# 	Token: head, TF-IDF: 0.10719
# 	Token: nothing, TF-IDF: 0.10356
# 	Token: newsweek, TF-IDF: 0.08449
#
#
# Beyonce Featuring Jay Z Drunk In Love 2014
#
#
# Pharrell Williams Happy 2014
# 	Token: roof, TF-IDF: 0.67502
# 	Token: truth, TF-IDF: 0.55635
# 	Token: down, TF-IDF: 0.34951
# 	Token: said, TF-IDF: 0.22746
# 	Token: do, TF-IDF: 0.19823
#
#
# John Legend All Of Me 2014
# 	Token: edges, TF-IDF: 0.28941
# 	Token: imperfections, TF-IDF: 0.28941
# 	Token: beginning, TF-IDF: 0.26729
# 	Token: winning, TF-IDF: 0.26729
# 	Token: ohoh, TF-IDF: 0.26729
#
#
# Iggy Azalea Featuring Charli XCX Fancy 2014
# 	Token: decline, TF-IDF: 1.02503
# 	Token: homophones, TF-IDF: 0.58953
# 	Token: homonyms, TF-IDF: 0.58953
# 	Token: allusions, TF-IDF: 0.58953
# 	Token: rhyme, TF-IDF: 0.48772
#
#
# Nicki Minaj Anaconda 2014
# 	Token: butt, TF-IDF: 0.64064
# 	Token: hun, TF-IDF: 0.36846
# 	Token: don, TF-IDF: 0.21775
# 	Token: club, TF-IDF: 0.21775
# 	Token: not, TF-IDF: 0.15908
#
#
# Iggy Azalea Featuring Rita Ora Black Widow 2014
# 	Token: ya, TF-IDF: 0.22244
# 	Token: weave, TF-IDF: 0.20501
# 	Token: harder, TF-IDF: 0.19509
# 	Token: crazy, TF-IDF: 0.17544
# 	Token: free, TF-IDF: 0.13348
#
#
# Bobby Shmurda Hot Boy 2014
# 	Token: shmurda, TF-IDF: 0.37898
# 	Token: krper, TF-IDF: 0.37898
# 	Token: belts, TF-IDF: 0.37898
# 	Token: stellt, TF-IDF: 0.37898
# 	Token: spirituosen, TF-IDF: 0.37898
#
#
# Beyonce 7/11 2014
# 	Token: air, TF-IDF: 0.86863
# 	Token: alcohol, TF-IDF: 0.40814
# 	Token: side, TF-IDF: 0.31625
# 	Token: up, TF-IDF: 0.26936
# 	Token: care, TF-IDF: 0.23102
#
#
# Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown Only 2014
# 	Token: only, TF-IDF: 0.20776
# 	Token: tape, TF-IDF: 0.13101
# 	Token: rooms, TF-IDF: 0.13101
# 	Token: nigga, TF-IDF: 0.12444
# 	Token: guns, TF-IDF: 0.121
#
#
# Big Sean Featuring E-40 I Don't F**k With You 2015
#
#
# Usher Featuring Juicy J I Don't Mind 2015
# 	Token: money, TF-IDF: 0.57864
# 	Token: mind, TF-IDF: 0.29047
# 	Token: biz, TF-IDF: 0.2513
# 	Token: ho, TF-IDF: 0.16876
# 	Token: home, TF-IDF: 0.13154
#
#
# Rihanna & Kanye West & Paul McCartney FourFiveSeconds 2015
# 	Token: wilding, TF-IDF: 0.47163
# 	Token: friday, TF-IDF: 0.43558
# 	Token: morning, TF-IDF: 0.29866
# 	Token: want, TF-IDF: 0.25848
# 	Token: weakness, TF-IDF: 0.23581
#
#
# The Weeknd Earned It (Fifty Shades Of Grey) 2015
# 	Token: winner, TF-IDF: 0.91229
# 	Token: album, TF-IDF: 0.08467
# 	Token: year, TF-IDF: 0.06714
# 	Token: space, TF-IDF: 0.06468
# 	Token: puth, TF-IDF: 0.05644
#
#
# Wiz Khalifa Featuring Charlie Puth See You Again 2015
# 	Token: again, TF-IDF: 0.44475
# 	Token: woooohohohohohoh, TF-IDF: 0.26094
# 	Token: began, TF-IDF: 0.22685
# 	Token: friend, TF-IDF: 0.14083
# 	Token: got, TF-IDF: 0.12119
#
#
# The Weeknd Can't Feel My Face 2015
# 	Token: oh, TF-IDF: 0.37034
# 	Token: numb, TF-IDF: 0.24117
# 	Token: woo, TF-IDF: 0.23414
# 	Token: come, TF-IDF: 0.16802
# 	Token: more, TF-IDF: 0.14367
#
#
# The Weeknd The Hills 2015
# 	Token: five, TF-IDF: 0.45077
# 	Token: ewedihalehu, TF-IDF: 0.18949
# 	Token: fikir, TF-IDF: 0.18949
# 	Token: simple, TF-IDF: 0.17501
# 	Token: side, TF-IDF: 0.14683
#
#
# Drake Hotline Bling 2015
# 	Token: bling, TF-IDF: 0.57658
# 	Token: phone, TF-IDF: 0.41136
# 	Token: thing, TF-IDF: 0.3128
# 	Token: else, TF-IDF: 0.23463
# 	Token: love, TF-IDF: 0.1646
#
#
# Drake Hotline Bling 2016
# 	Token: bling, TF-IDF: 0.57658
# 	Token: phone, TF-IDF: 0.41136
# 	Token: thing, TF-IDF: 0.3128
# 	Token: else, TF-IDF: 0.23463
# 	Token: love, TF-IDF: 0.1646
#
#
# Alessia Cara Here 2016
# 	Token: here, TF-IDF: 0.72343
# 	Token: this, TF-IDF: 0.11538
# 	Token: uninterested, TF-IDF: 0.09308
# 	Token: indifferent, TF-IDF: 0.09308
# 	Token: wellbeing, TF-IDF: 0.09308
#
#
# Rihanna Featuring Drake Work 2016
# 	Token: arbeiten, TF-IDF: 0.50265
# 	Token: muss, TF-IDF: 0.27925
# 	Token: mich, TF-IDF: 0.2234
# 	Token: mache, TF-IDF: 0.2234
# 	Token: mehr, TF-IDF: 0.2234
#
#
# Drake Summer Sixteen 2016
# 	Token: sixteen, TF-IDF: 0.34591
# 	Token: revenge, TF-IDF: 0.28825
# 	Token: looking, TF-IDF: 0.27133
# 	Token: seasons, TF-IDF: 0.17295
# 	Token: clean, TF-IDF: 0.1628
#
#
# Desiigner Panda 2016
# 	Token: panda, TF-IDF: 0.64176
# 	Token: phantom, TF-IDF: 0.4011
# 	Token: atlanta, TF-IDF: 0.23069
# 	Token: scammers, TF-IDF: 0.23069
# 	Token: panty, TF-IDF: 0.23069
#
#
# Drake Featuring WizKid & Kyla One Dance 2016
# 	Token: dance, TF-IDF: 0.31218
# 	Token: where, TF-IDF: 0.29699
# 	Token: hand, TF-IDF: 0.27768
# 	Token: go, TF-IDF: 0.16759
# 	Token: style, TF-IDF: 0.13302
#
#
# Rihanna Needed Me 2016
# 	Token: carriage, TF-IDF: 0.24678
# 	Token: imagine, TF-IDF: 0.24678
# 	Token: twisted, TF-IDF: 0.20416
# 	Token: savage, TF-IDF: 0.20416
# 	Token: list, TF-IDF: 0.19568
# D.R.A.M. Featuring Lil Yachty Broccoli 2016
# 	Token: sorry, TF-IDF: 0.35553
# 	Token: ohhhh, TF-IDF: 0.34388
# 	Token: crayaaaazy, TF-IDF: 0.18617
# 	Token: aaazy, TF-IDF: 0.18617
# 	Token: lay, TF-IDF: 0.18617
#
#
# The Weeknd Featuring Daft Punk Starboy 2016
# 	Token: ah, TF-IDF: 0.73491
# 	Token: hecho, TF-IDF: 0.61254
# 	Token: starboy, TF-IDF: 0.61254
# 	Token: central, TF-IDF: 0.2297
# 	Token: bano, TF-IDF: 0.2297
#
#
# Rae Sremmurd Featuring Gucci Mane Black Beatles 2016
# 	Token: pleaser, TF-IDF: 0.27224
# 	Token: geezer, TF-IDF: 0.27224
# 	Token: even, TF-IDF: 0.27224
# 	Token: drinking, TF-IDF: 0.27224
# 	Token: needle, TF-IDF: 0.27224
#
#
# The Weeknd Featuring Daft Punk Starboy 2017
# 	Token: ah, TF-IDF: 0.73491
# 	Token: hecho, TF-IDF: 0.61254
# 	Token: starboy, TF-IDF: 0.61254
# 	Token: central, TF-IDF: 0.2297
# 	Token: bano, TF-IDF: 0.2297
#
#
# Rae Sremmurd Featuring Gucci Mane Black Beatles 2017
# 	Token: pleaser, TF-IDF: 0.27224
# 	Token: geezer, TF-IDF: 0.27224
# 	Token: even, TF-IDF: 0.27224
# 	Token: drinking, TF-IDF: 0.27224
# 	Token: needle, TF-IDF: 0.27224
#
#
# Migos Featuring Lil Uzi Vert Bad And Boujee 2017
# 	Token: blam, TF-IDF: 0.18296
# 	Token: advance, TF-IDF: 0.18296
# 	Token: ladder, TF-IDF: 0.18296
# 	Token: seeds, TF-IDF: 0.18296
# 	Token: capish, TF-IDF: 0.18296
#
#
# Bruno Mars That's What I Like 2017
# 	Token: like, TF-IDF: 0.53049
# 	Token: bright, TF-IDF: 0.19611
# 	Token: ice, TF-IDF: 0.19611
# 	Token: white, TF-IDF: 0.19611
# 	Token: player, TF-IDF: 0.1416
#
#
# Kendrick Lamar Humble. 2017
# 	Token: ayy, TF-IDF: 0.78773
# 	Token: funk, TF-IDF: 0.66322
# 	Token: allowances, TF-IDF: 0.16581
# 	Token: analysts, TF-IDF: 0.16581
# 	Token: paystub, TF-IDF: 0.16581
#
#
# DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne I'm The One 2017
# 	Token: ehoh, TF-IDF: 0.73183
# 	Token: one, TF-IDF: 0.47691
# 	Token: imitators, TF-IDF: 0.18296
# 	Token: dawn, TF-IDF: 0.13976
# 	Token: truth, TF-IDF: 0.13109
#
#
# DJ Khaled Featuring Rihanna & Bryson Tiller Wild Thoughts 2017
# 	Token: gedanken, TF-IDF: 0.85577
# 	Token: wild, TF-IDF: 0.69698
# 	Token: sein, TF-IDF: 0.25673
# 	Token: mitnehmen, TF-IDF: 0.17115
# 	Token: khaled, TF-IDF: 0.14879
#
#
# Cardi B Bodak Yellow (Money Moves) 2017
# 	Token: account, TF-IDF: 0.58139
# 	Token: broke, TF-IDF: 0.49834
# 	Token: dumb, TF-IDF: 0.41217
# 	Token: yadadadadadadada, TF-IDF: 0.35971
# 	Token: moves, TF-IDF: 0.28523
#
#
# Post Malone Featuring 21 Savage Rockstar 2017
# 	Token: rockstar, TF-IDF: 0.44548
# 	Token: geschluckt, TF-IDF: 0.33411
# 	Token: rasta, TF-IDF: 0.33411
# 	Token: herbei, TF-IDF: 0.33411
# 	Token: shottas, TF-IDF: 0.33411
#
#
# Post Malone Featuring 21 Savage Rockstar 2018
# 	Token: rockstar, TF-IDF: 0.44548
# 	Token: geschluckt, TF-IDF: 0.33411
# 	Token: rasta, TF-IDF: 0.33411
# 	Token: herbei, TF-IDF: 0.33411
# 	Token: shottas, TF-IDF: 0.33411
#
#
# Bruno Mars & Cardi B Finesse 2018
# 	Token: finesse, TF-IDF: 0.8843
# 	Token: sense, TF-IDF: 0.46126
# 	Token: ayy, TF-IDF: 0.24007
# 	Token: measurements, TF-IDF: 0.17686
# 	Token: on, TF-IDF: 0.17361
#
#
# Drake God's Plan 2018
# 	Token: wishing, TF-IDF: 0.53058
# 	Token: things, TF-IDF: 0.45815
# 	Token: wait, TF-IDF: 0.32424
# 	Token: yuh, TF-IDF: 0.26337
# 	Token: ayy, TF-IDF: 0.21606
#
#
# Drake Nice For What 2018
# 	Token: jump, TF-IDF: 0.2154
# 	Token: me, TF-IDF: 0.19113
# 	Token: angles, TF-IDF: 0.16155
# 	Token: niggas, TF-IDF: 0.15446
# 	Token: fabo, TF-IDF: 0.11661
#
#
# Childish Gambino This Is America 2018
# 	Token: somebody, TF-IDF: 0.58885
# 	Token: now, TF-IDF: 0.25043
# 	Token: away, TF-IDF: 0.18471
# 	Token: dog, TF-IDF: 0.17247
# 	Token: ayy, TF-IDF: 0.15324
#
#
# Post Malone Featuring Ty Dolla $ign Psycho 2018
# 	Token: ayy, TF-IDF: 0.3376
# 	Token: boatload, TF-IDF: 0.33161
# 	Token: soaked, TF-IDF: 0.33161
# 	Token: michael, TF-IDF: 0.28829
# 	Token: cold, TF-IDF: 0.21963
#
#
# XXXTENTACION Sad! 2018
# 	Token: uh, TF-IDF: 1.31307
# 	Token: yeah, TF-IDF: 0.25109
# 	Token: contagious, TF-IDF: 0.19651
# 	Token: weep, TF-IDF: 0.19651
# 	Token: found, TF-IDF: 0.13337
#
#
# Cardi B, Bad Bunny & J Balvin I Like It 2018
# 	Token: yeh, TF-IDF: 0.34231
# 	Token: b, TF-IDF: 0.23233
# 	Token: that, TF-IDF: 0.23152
# 	Token: can, TF-IDF: 0.20055
# 	Token: deals, TF-IDF: 0.17115
#
#
# Drake In My Feelings 2018
# 	Token: always, TF-IDF: 0.53386
# 	Token: riding, TF-IDF: 0.4302
# 	Token: trapmoneybenny, TF-IDF: 0.2151
# 	Token: ya, TF-IDF: 0.16908
# 	Token: wraith, TF-IDF: 0.13244
#
#
# Juice WRLD Lucid Dreams 2018
# 	Token: one, TF-IDF: 0.28582
# 	Token: head, TF-IDF: 0.27838
# 	Token: room, TF-IDF: 0.20979
# 	Token: break, TF-IDF: 0.16124
# 	Token: fake, TF-IDF: 0.14628
#
#
# Lil Wayne Featuring Kendrick Lamar Mona Lisa 2018
# 	Token: nigga, TF-IDF: 0.25845
# 	Token: lisa, TF-IDF: 0.14841
# 	Token: bitches, TF-IDF: 0.12902
# 	Token: him, TF-IDF: 0.09583
# 	Token: followed, TF-IDF: 0.06854
#
#
# Kodak Black Featuring Travis Scott & Offset ZEZE 2018
# 	Token: public, TF-IDF: 0.13769
# 	Token: outside, TF-IDF: 0.13103
# 	Token: truck, TF-IDF: 0.13103
# 	Token: lemonade, TF-IDF: 0.07919
# 	Token: gates, TF-IDF: 0.07919
#
#
# Travis Scott Sicko Mode 2018
# 	Token: yeah, TF-IDF: 0.17487
# 	Token: said, TF-IDF: 0.1727
# 	Token: ayy, TF-IDF: 0.15004
# 	Token: land, TF-IDF: 0.12193
# 	Token: deep, TF-IDF: 0.11687

# %% [markdown]
# The tf-idf scheme reduces documents of arbitrary length to fixed-length lists of
# numbers. While the tf-idf reduction has some appealing features—notably in its basic identification of sets
# of words that are discriminative for documents in the collection—the approach also provides a relatively small amount of reduction in description length and reveals little in the way of inter- or intradocument statistical structure.
#
# This line of thinking leads to the latent Dirichlet allocation (LDA) model that we present in the
# current paper.
# It is important to emphasize that an assumption of exchangeability is not equivalent to an assumption that the random variables are independent and identically distributed. Rather, exchangeability essentially can be interpreted as meaning “conditionally independent and identically distributed,” where the conditioning is with respect to an underlying latent parameter of a probability
# distribution. Conditionally, the joint distribution of the random variables is simple and factored
# while marginally over the latent parameter, the joint distribution can be quite complex. Thus, while
# an assumption of exchangeability is clearly a major simplifying assumption in the domain of text
# modeling, and its principal justification is that it leads to methods that are computationally efficient,
# the exchangeability assumptions do not necessarily lead to methods that are restricted to simple
# frequency counts or linear operations.
#
# Paper: http://www.cs.columbia.edu/~blei/papers/BleiNgJordan2003.pdf

# %%
len(filter_1990s_token_fql)
# Out:
# 3522

# %%
len(filter_2000s_token_fql)
# Out:
# 2779

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %%
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
no_features = 1000
no_topics = 3
no_top_words = 5

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features)
tf = tf_vectorizer.fit_transform(filter_1990s_token)
tf_feature_names = tf_vectorizer.get_feature_names()


# Run LDA
lda = LatentDirichletAllocation(n_topics=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

display_topics(lda, tf_feature_names, no_top_words)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# Topic 0:
# yeah know babe need night
# Topic 1:
# time shit go right bitch
# Topic 2:
# baby love girl alone way

# %%
tf = tf_vectorizer.fit_transform(filter_2000s_token)
tf_feature_names = tf_vectorizer.get_feature_names()


# Run LDA
lda = LatentDirichletAllocation(n_topics=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

display_topics(lda, tf_feature_names, no_top_words)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# Topic 0:
# baby oh ya thing us
# Topic 1:
# one girl love life time
# Topic 2:
# yeah back diamond right shit

# %% [markdown]
# ### Feature Extraction
